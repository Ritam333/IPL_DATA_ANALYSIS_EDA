# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df1=pd.read_csv(r'F:\ipl\deliveries.csv')

# %%
df1.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
df1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2=pd.read_csv(r'F:\ipl\matches.csv')

# %%
df2.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.head(10)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
# 5                      Sawai Mansingh Stadium             Rajasthan Royals
# 6   Rajiv Gandhi International Stadium, Uppal              Deccan Chargers
# 7             MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 8   Rajiv Gandhi International Stadium, Uppal              Deccan Chargers
# 9  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
# 5              Kings XI Punjab              Kings XI Punjab           bat
# 6             Delhi Daredevils              Deccan Chargers           bat
# 7               Mumbai Indians               Mumbai Indians         field
# 8             Rajasthan Royals             Rajasthan Royals         field
# 9               Mumbai Indians               Mumbai Indians         field
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
# 5             Rajasthan Royals  wickets            6.0        167.0
# 6             Delhi Daredevils  wickets            9.0        143.0
# 7          Chennai Super Kings     runs            6.0        209.0
# 8             Rajasthan Royals  wickets            3.0        215.0
# 9              Kings XI Punjab     runs           66.0        183.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan
# 5          20.0          N    NaN  Aleem Dar       RB Tiffin
# 6          20.0          N    NaN  IL Howell       AM Saheba
# 7          20.0          N    NaN  DJ Harper  GA Pratapkumar
# 8          20.0          N    NaN  Asad Rauf       MR Benson
# 9          20.0          N    NaN  Aleem Dar       AM Saheba

# %%
df2.shape
# Out:
# (1095, 20)

# %% [markdown]
# ## HANDLING MISSING VALUES

# %%
df2.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df2['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df2['method'].fillna('No method applied',inplace=True)

# %%
df2['target_overs'].fillna(df2['target_overs'].median(),inplace=True)

# %%
df2['target_runs'].fillna(df2['target_runs'].median(),inplace=True)

# %%
df2['result_margin'].fillna(df2['result_margin'].median(),inplace=True)

# %%
df2['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah', 'Navi Mumbai', 'Lucknow', 'Guwahati', 'Mohali'],
#       dtype=object)

# %% [markdown]
# ## assigning the city name according the venue name

# %%
df2[df2['city'].isnull()]['venue'].unique()
# Out:
# array(['Sharjah Cricket Stadium', 'Dubai International Cricket Stadium'],
#       dtype=object)

# %%
df2.loc[df2['venue']=='Sharjah Cricket Stadium','city']='Sharjah'
df2.loc[df2['venue']=='Dubai International Cricket Stadium','city']='Dubai'

# %%
df2['winner'].fillna('No Result', inplace=True)
df2['player_of_match'].fillna('No Result',inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df2['venue'].value_counts()
# Out:
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# MA Chidambaram Stadium, Chepauk, Chennai                                 28
# Narendra Modi Stadium, Ahmedabad                                         24
# Maharashtra Cricket Association Stadium                                  22
# Dr DY Patil Sports Academy, Mumbai                                       20
# Brabourne Stadium, Mumbai                                                17
# Dr DY Patil Sports Academy                                               17
# Eden Gardens, Kolkata                                                    16
# Subrata Roy Sahara Stadium                                               16
# Arun Jaitley Stadium, Delhi                                              16
# Rajiv Gandhi International Stadium                                       15
# M.Chinnaswamy Stadium                                                    15
# Kingsmead                                                                15
# Arun Jaitley Stadium                                                     14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    14
# M Chinnaswamy Stadium, Bengaluru                                         14
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     13
# Maharashtra Cricket Association Stadium, Pune                            13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium                      13
# SuperSport Park                                                          12
# Sardar Patel Stadium, Motera                                             12
# Punjab Cricket Association IS Bindra Stadium, Mohali                     11
# Sawai Mansingh Stadium, Jaipur                                           10
# Saurashtra Cricket Association Stadium                                   10
# Brabourne Stadium                                                        10
# Punjab Cricket Association IS Bindra Stadium                             10
# Himachal Pradesh Cricket Association Stadium                              9
# MA Chidambaram Stadium                                                    9
# Holkar Cricket Stadium                                                    9
# New Wanderers Stadium                                                     8
# Zayed Cricket Stadium, Abu Dhabi                                          8
# JSCA International Stadium Complex                                        7
# Barabati Stadium                                                          7
# St George's Park                                                          7
# Newlands                                                                  7
# Shaheed Veer Narayan Singh International Stadium                          6
# Nehru Stadium                                                             5
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh          5
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        5
# Green Park                                                                4
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  4
# Vidarbha Cricket Association Stadium, Jamtha                              3
# De Beers Diamond Oval                                                     3
# Buffalo Park                                                              3
# Barsapara Cricket Stadium, Guwahati                                       3
# OUTsurance Oval                                                           2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam        2
# Name: venue, dtype: int64

# %% [markdown]
# # Changes the stadium names correctly such as 'Eden Gardens' and 'Eden Gardens, Kolkata' is same stadium

# %%
df2[df2['venue'].str.startswith('Eden')]['venue'].unique()
# Out:
# array(['Eden Gardens', 'Eden Gardens, Kolkata'], dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Eden Gardens, Kolkata','Eden Gardens')

# %%
df2[df2['venue'].str.startswith('Wankhede')]['venue'].unique()
# Out:
# array(['Wankhede Stadium', 'Wankhede Stadium, Mumbai'], dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Wankhede Stadium, Mumbai','Wankhede Stadium')

# %%
df2[df2['venue'].str.startswith('M Chinnaswamy')]['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium', 'M Chinnaswamy Stadium, Bengaluru'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('M Chinnaswamy Stadium, Bengaluru','M Chinnaswamy Stadium')

# %%
df2['venue']=df2['venue'].replace('M.Chinnaswamy Stadium','M Chinnaswamy Stadium')

# %%
df2[df2['venue'].str.startswith('Rajiv')]['venue'].unique()
# Out:
# array(['Rajiv Gandhi International Stadium, Uppal',
#        'Rajiv Gandhi International Stadium',
#        'Rajiv Gandhi International Stadium, Uppal, Hyderabad'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].replace(['Rajiv Gandhi International Stadium, Uppal',
        'Rajiv Gandhi International Stadium, Uppal, Hyderabad'],'Rajiv Gandhi International Stadium')

# %%
df2[df2['venue'].str.startswith('MA Chidambaram')]['venue'].unique()
# Out:
# array(['MA Chidambaram Stadium, Chepauk', 'MA Chidambaram Stadium',
#        'MA Chidambaram Stadium, Chepauk, Chennai'], dtype=object)

# %%
df2['venue']=df2['venue'].replace(['MA Chidambaram Stadium, Chepauk',
        'MA Chidambaram Stadium, Chepauk, Chennai'],'MA Chidambaram Stadium')

# %%
df2[df2['venue'].str.startswith('Sawai')]['venue'].unique()
# Out:
# array(['Sawai Mansingh Stadium', 'Sawai Mansingh Stadium, Jaipur'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Sawai Mansingh Stadium, Jaipur','Sawai Mansingh Stadium')

# %%
df2[df2['venue'].str.startswith('Punjab')]['venue'].unique()
# Out:
# array(['Punjab Cricket Association Stadium, Mohali',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Punjab Cricket Association IS Bindra Stadium',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].replace(['Punjab Cricket Association Stadium, Mohali',
       'Punjab Cricket Association IS Bindra Stadium, Mohali',
       'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh'],'Punjab Cricket Association IS Bindra Stadium')

# %%
df2[df2['venue'].str.startswith('Maharashtra')]['venue'].unique()
# Out:
# array(['Maharashtra Cricket Association Stadium',
#        'Maharashtra Cricket Association Stadium, Pune'], dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Maharashtra Cricket Association Stadium, Pune','Maharashtra Cricket Association Stadium')

# %%
df2[df2['venue'].str.startswith('Dr DY')]['venue'].unique()
# Out:
# array(['Dr DY Patil Sports Academy', 'Dr DY Patil Sports Academy, Mumbai'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Dr DY Patil Sports Academy, Mumbai','Dr DY Patil Sports Academy')

# %%
df2[df2['venue'].str.startswith('Brabourne')]['venue'].unique()
# Out:
# array(['Brabourne Stadium', 'Brabourne Stadium, Mumbai'], dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Brabourne Stadium, Mumbai','Brabourne Stadium')

# %%
df2[df2['venue'].str.startswith('Arun Jaitley')]['venue'].unique()
# Out:
# array(['Arun Jaitley Stadium', 'Arun Jaitley Stadium, Delhi'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Arun Jaitley Stadium, Delhi','Arun Jaitley Stadium')

# %%
df2['venue']=df2['venue'].str.replace('Feroz Shah Kotla','Arun Jaitley Stadium')

# %%
df2[df2['venue'].str.startswith('Dr. Y.S.')]['venue'].unique()
# Out:
# array(['Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam','Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',regex=False)

# %%
df2[df2['venue'].str.startswith('Himachal')]['venue'].unique()
# Out:
# array(['Himachal Pradesh Cricket Association Stadium',
#        'Himachal Pradesh Cricket Association Stadium, Dharamsala'],
#       dtype=object)

# %%
df2['venue']=df2['venue'].str.replace('Himachal Pradesh Cricket Association Stadium, Dharamsala','Himachal Pradesh Cricket Association Stadium')

# %% [markdown]
# #  **Q.1 ---> FIND THE STADIUM WHERE THE MOST MATCH PLAYED (2008-2024)**

# %%
Stadium=df2['venue'].value_counts().reset_index()
Stadium.columns=['Stadium','Number of Matches']

# %%
Stadium.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_b132e_row0_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_b132e_row1_col1 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_b132e_row2_col1 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_b132e_row3_col1 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_b132e_row4_col1 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_b132e_row5_col1 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_b132e_row6_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_b132e_row7_col1 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_b132e_row8_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_b132e_row9_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_b132e_row10_col1 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_b132e_row11_col1 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_b132e_row12_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_b132e_row13_col1 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_b132e_row14_col1 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_b132e_row15_col1 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_b132e_row16_col1, #T_b132e_row17_col1 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_b132e_row18_col1 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_b132e_row19_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_b132e_row20_col1, #T_b132e_row21_col1 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_b132e_row22_col1 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_b132e_row23_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_b132e_row24_col1, #T_b132e_row25_col1 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_b132e_row26_col1, #T_b132e_row27_col1, #T_b132e_row28_col1, #T_b132e_row29_col1 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_b132e_row30_col1 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_b132e_row31_col1, #T_b132e_row32_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_b132e_row33_col1 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_b132e_row34_col1, #T_b132e_row35_col1, #T_b132e_row36_col1, #T_b132e_row37_col1 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_b132e_row38_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b132e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b132e_level0_col0" class="col_heading level0 col0" >Stadium</th>
#       <th id="T_b132e_level0_col1" class="col_heading level0 col1" >Number of Matches</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b132e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b132e_row0_col0" class="data row0 col0" >Wankhede Stadium</td>
#       <td id="T_b132e_row0_col1" class="data row0 col1" >118</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b132e_row1_col0" class="data row1 col0" >M Chinnaswamy Stadium</td>
#       <td id="T_b132e_row1_col1" class="data row1 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b132e_row2_col0" class="data row2 col0" >Eden Gardens</td>
#       <td id="T_b132e_row2_col1" class="data row2 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b132e_row3_col0" class="data row3 col0" >Arun Jaitley Stadium</td>
#       <td id="T_b132e_row3_col1" class="data row3 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b132e_row4_col0" class="data row4 col0" >MA Chidambaram Stadium</td>
#       <td id="T_b132e_row4_col1" class="data row4 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b132e_row5_col0" class="data row5 col0" >Rajiv Gandhi International Stadium</td>
#       <td id="T_b132e_row5_col1" class="data row5 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b132e_row6_col0" class="data row6 col0" >Punjab Cricket Association IS Bindra Stadium</td>
#       <td id="T_b132e_row6_col1" class="data row6 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b132e_row7_col0" class="data row7 col0" >Sawai Mansingh Stadium</td>
#       <td id="T_b132e_row7_col1" class="data row7 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b132e_row8_col0" class="data row8 col0" >Dubai International Cricket Stadium</td>
#       <td id="T_b132e_row8_col1" class="data row8 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b132e_row9_col0" class="data row9 col0" >Dr DY Patil Sports Academy</td>
#       <td id="T_b132e_row9_col1" class="data row9 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b132e_row10_col0" class="data row10 col0" >Maharashtra Cricket Association Stadium</td>
#       <td id="T_b132e_row10_col1" class="data row10 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b132e_row11_col0" class="data row11 col0" >Sheikh Zayed Stadium</td>
#       <td id="T_b132e_row11_col1" class="data row11 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b132e_row12_col0" class="data row12 col0" >Sharjah Cricket Stadium</td>
#       <td id="T_b132e_row12_col1" class="data row12 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b132e_row13_col0" class="data row13 col0" >Brabourne Stadium</td>
#       <td id="T_b132e_row13_col1" class="data row13 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b132e_row14_col0" class="data row14 col0" >Narendra Modi Stadium, Ahmedabad</td>
#       <td id="T_b132e_row14_col1" class="data row14 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b132e_row15_col0" class="data row15 col0" >Subrata Roy Sahara Stadium</td>
#       <td id="T_b132e_row15_col1" class="data row15 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b132e_row16_col0" class="data row16 col0" >Kingsmead</td>
#       <td id="T_b132e_row16_col1" class="data row16 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b132e_row17_col0" class="data row17 col0" >Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium</td>
#       <td id="T_b132e_row17_col1" class="data row17 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b132e_row18_col0" class="data row18 col0" >Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow</td>
#       <td id="T_b132e_row18_col1" class="data row18 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b132e_row19_col0" class="data row19 col0" >Himachal Pradesh Cricket Association Stadium</td>
#       <td id="T_b132e_row19_col1" class="data row19 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b132e_row20_col0" class="data row20 col0" >SuperSport Park</td>
#       <td id="T_b132e_row20_col1" class="data row20 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b132e_level0_row21" class="row_heading level0 row21" >21</t

# %% [markdown]
# ## CONCLUSION ->>

# %% [markdown]
#  ### *TILL NOW Wankhede Stadium HOLDS THE HIGHEST NUMBER OF MATCH PLAYED*

# %% [markdown]
# # **Q.2 ---> TOTAL RUNS ACCROSS SEASON**

# %%
season_data=df2[['id','season']].merge(df1,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
season=season_data.groupby('season')['total_runs'].sum().reset_index()

# %%
p=season.set_index('season')

# %%
fig=px.line(p,x=p.index,y='total_runs',title='TOTAL RUNS ACCROSS SEASON',labels={'total_runs':'TOTAL RUNS'})
fig.update_layout(template='simple_white',title_font={'size':26})
fig.show()

# %% [markdown]
# ## *CONCLUSION --> DAY BY DAY THE RUNS BUBBLE IN IPL INCREASING*

# %% [markdown]
# ## **Q.3 ---> UMPIRE WITH MOST NUMBER OF UMPIRING**

# %%
ump=pd.concat([df2['umpire1'],df2['umpire2']])

# %%
ump=ump.value_counts().reset_index()

# %%
ump.columns=['Name','Number of Matches']

# %%
ump.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_782b0_row0_col1, #T_782b0_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_782b0_row2_col1 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_782b0_row3_col1 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_782b0_row4_col1 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_782b0_row5_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_782b0_row6_col1 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_782b0_row7_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_782b0_row8_col1 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_782b0_row9_col1 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_782b0_row10_col1 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_782b0_row11_col1 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_782b0_row12_col1 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_782b0_row13_col1 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_782b0_row14_col1 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_782b0_row15_col1, #T_782b0_row16_col1 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_782b0_row17_col1 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_782b0_row18_col1 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_782b0_row19_col1 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_782b0_row20_col1, #T_782b0_row21_col1, #T_782b0_row22_col1 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_782b0_row23_col1 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_782b0_row24_col1, #T_782b0_row25_col1 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_782b0_row26_col1, #T_782b0_row27_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_782b0_row28_col1 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_782b0_row29_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_782b0_row30_col1, #T_782b0_row31_col1 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_782b0_row32_col1 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_782b0_row33_col1, #T_782b0_row34_col1 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_782b0_row35_col1, #T_782b0_row36_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_782b0_row37_col1 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_782b0_row38_col1 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_782b0_row39_col1, #T_782b0_row40_col1, #T_782b0_row41_col1 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_782b0_row42_col1 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_782b0_row43_col1, #T_782b0_row44_col1, #T_782b0_row45_col1 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_782b0_row46_col1, #T_782b0_row47_col1, #T_782b0_row48_col1 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_782b0_row49_col1 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_782b0_row50_col1, #T_782b0_row51_col1, #T_782b0_row52_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_782b0_row53_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_782b0_row54_col1, #T_782b0_row55_col1, #T_782b0_row56_col1 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_782b0_row57_col1, #T_782b0_row58_col1, #T_782b0_row59_col1, #T_782b0_row60_col1, #T_782b0_row61_col1, #T_782b0_row62_col1, #T_782b0_row63_col1, #T_782b0_row64_col1 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_782b0_row65_col1 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_782b0_row66_col1 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_782b0_row67_col1, #T_782b0_row68_col1 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_782b0_row69_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_782b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_782b0_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_782b0_level0_col1" class="col_heading level0 col1" >Number of Matches</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_782b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_782b0_row0_col0" class="data row0 col0" >S Ravi</td>
#       <td id="T_782b0_row0_col1" class="data row0 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_782b0_row1_col0" class="data row1 col0" >AK Chaudhary</td>
#       <td id="T_782b0_row1_col1" class="data row1 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_782b0_row2_col0" class="data row2 col0" >Nitin Menon</td>
#       <td id="T_782b0_row2_col1" class="data row2 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_782b0_row3_col0" class="data row3 col0" >HDPK Dharmasena</td>
#       <td id="T_782b0_row3_col1" class="data row3 col1" >98</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_782b0_row4_col0" class="data row4 col0" >C Shamshuddin</td>
#       <td id="T_782b0_row4_col1" class="data row4 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_782b0_row5_col0" class="data row5 col0" >CB Gaffaney</td>
#       <td id="T_782b0_row5_col1" class="data row5 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_782b0_row6_col0" class="data row6 col0" >KN Ananthapadmanabhan</td>
#       <td id="T_782b0_row6_col1" class="data row6 col1" >72</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_782b0_row7_col0" class="data row7 col0" >M Erasmus</td>
#       <td id="T_782b0_row7_col1" class="data row7 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_782b0_row8_col0" class="data row8 col0" >VK Sharma</td>
#       <td id="T_782b0_row8_col1" class="data row8 col1" >65</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_782b0_row9_col0" class="data row9 col0" >BNJ Oxenford</td>
#       <td id="T_782b0_row9_col1" class="data row9 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_782b0_row10_col0" class="data row10 col0" >RJ Tucker</td>
#       <td id="T_782b0_row10_col1" class="data row10 col1" >62</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_782b0_row11_col0" class="data row11 col0" >CK Nandan</td>
#       <td id="T_782b0_row11_col1" class="data row11 col1" >59</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_782b0_row12_col0" class="data row12 col0" >VA Kulkarni</td>
#       <td id="T_782b0_row12_col1" class="data row12 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_782b0_row13_col0" class="data row13 col0" >SJA Taufel</td>
#       <td id="T_782b0_row13_col1" class="data row13 col1" >55</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_782b0_row14_col0" class="data row14 col0" >Asad Rauf</td>
#       <td id="T_782b0_row14_col1" class="data row14 col1" >51</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_782b0_row15_col0" class="data row15 col0" >BR Doctrove</td>
#       <td id="T_782b0_row15_col1" class="data row15 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_782b0_row16_col0" class="data row16 col0" >YC Barde</td>
#       <td id="T_782b0_row16_col1" class="data row16 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_782b0_level0_row17" class="row_headi

# %% [markdown]
# ### CONCLUSION -- *S RAVI AND AK CHAUDHARY HAS UMPAIRED IN 131 MATCHES ,FOLLOWED BY  NITIN MENON WHO HAS UMPAIRED 104 MATCHES*

# %% [markdown]
# ##  **Q.3 ---> MOST NUMBER OF TOSS WINNER IN THE IPL SEASON**

# %% [markdown]
# #### IDENTIFY AND REPLACE THE STADIUM NAME WHICH IS SAME SUCH AS  'Rising Pune Supergiants' AND  'Rising Pune Supergiant'  BOTH ARE SAME
# #### 'Delhi Daredevils' AND 'Delhi Capitals' BOTH ARE SAME TEAM BUT CHANGES THEIR NAME

# %%
df2[df2['toss_winner'].str.startswith('Rising Pune')]['toss_winner'].unique()
# Out:
# array(['Rising Pune Supergiants', 'Rising Pune Supergiant'], dtype=object)

# %%
df2['toss_winner']=df2['toss_winner'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df2[df2['toss_winner'].str.startswith('Royal')]['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Royal Challengers Bengaluru'],
#       dtype=object)

# %%
df2['toss_winner']=df2['toss_winner'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')

# %%
df2[df2['toss_winner'].str.startswith('Delhi')]['toss_winner'].unique()
# Out:
# array(['Delhi Daredevils', 'Delhi Capitals'], dtype=object)

# %%
df2['toss_winner']=df2['toss_winner'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df2['toss_winner']=df2['toss_winner'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
df2['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 143
# Delhi Capitals                 130
# Chennai Super Kings            122
# Kolkata Knight Riders          122
# Royal Challengers Bangalore    121
# Rajasthan Royals               120
# Punjab Kings                   109
# Sunrisers Hyderabad             88
# Deccan Chargers                 43
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Rising Pune Supergiant          13
# Kochi Tuskers Kerala             8
# Name: toss_winner, dtype: int64

# %%
toss=df2['toss_winner'].value_counts().reset_index()
toss.columns=['toss_winner','count']

# %%
fig=px.bar(toss,x='toss_winner',y='count',title='Total Toss Winner',color_discrete_sequence=['#40E0D0'])
fig.update_layout(template='simple_white',width=800, 
    height=400)
fig.show()
# Out:
# <div>                            <div id="f3c3e7e9-1e4d-488f-a62c-3707736d773c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3c3e7e9-1e4d-488f-a62c-3707736d773c")) {                    Plotly.newPlot(                        "f3c3e7e9-1e4d-488f-a62c-3707736d773c",                        [{"alignmentgroup":"True","hovertemplate":"toss_winner=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#40E0D0","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mumbai Indians","Delhi Capitals","Chennai Super Kings","Kolkata Knight Riders","Royal Challengers Bangalore","Rajasthan Royals","Punjab Kings","Sunrisers Hyderabad","Deccan Chargers","Gujarat Titans","Pune Warriors","Lucknow Super Giants","Gujarat Lions","Rising Pune Supergiant","Kochi Tuskers Kerala"],"xaxis":"x","y":[143,130,122,122,121,120,109,88,43,22,20,19,15,13,8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444 ...

# %% [markdown]
# ## *CONCLUSION -- Mumbai Indians HAS WON THE HIGHEST NUMBER OF TOSS (143) , FOLLOWED BY DELHI CAPITALS (130)*

# %% [markdown]
# # **Q.4 --> WHICH DECISION HAVE MADE AFTER TOSS WINNING**

# %%
toss_series=df2.toss_decision.value_counts()

# %%
toss_series
# Out:
# field    704
# bat      391
# Name: toss_decision, dtype: int64

# %%
labels=(np.array(toss_series.index))
labels
# Out:
# array(['field', 'bat'], dtype=object)

# %%
values=(np.array(toss_series/toss_series.sum())*100)

# %%
values
# Out:
# array([64.29223744, 35.70776256])

# %%
fig=go.Figure(

    data=go.Pie(
    
    labels=labels,values=values,hole=.3
        
    )
)

fig.update_traces(hoverinfo='label+percent',textinfo='label+percent')
fig.update_layout(title='Decission Made After Toss Winning')
fig.show()
# Out:
# <div>                            <div id="165764bc-dc09-4f3f-8de8-eed85d3e66ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("165764bc-dc09-4f3f-8de8-eed85d3e66ac")) {                    Plotly.newPlot(                        "165764bc-dc09-4f3f-8de8-eed85d3e66ac",                        [{"hole":0.3,"labels":["field","bat"],"values":[64.29223744292237,35.70776255707763],"type":"pie","hoverinfo":"label+percent","textinfo":"label+percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorb ...
#
# var gd = document.getElementById('165764bc-dc09-4f3f-8de8-eed85d3e66ac');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!

# %% [markdown]
# ### *CONCLUSION --- ITS A TENDS TO CHOOSE FIELD FIRST AFTER WINNING THE TOSS*

# %% [markdown]
# # **Q.5 ---> VENUE WISE TOSS WIN MATCH WIN PERCENTAGE**

# %%
df2['toss_winner_won']= (df2['toss_winner']==df2['winner'])

# %%
result=df2.groupby('venue',as_index=False).agg(

    total_match=('id','count'),
    toss_winner_matches=('toss_winner_won','sum')
).sort_values(by='total_match',ascending=False)

# %%
result['toss_win_match_win_percentage'] = (result['toss_winner_matches'] / result['total_match']) * 100

result=result.reset_index(drop=1)
result.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_763b7_row0_col1, #T_763b7_row0_col2, #T_763b7_row33_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_763b7_row0_col3 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_763b7_row1_col1 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_763b7_row1_col2, #T_763b7_row7_col3 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_763b7_row1_col3 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_763b7_row2_col1, #T_763b7_row2_col2 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_763b7_row2_col3 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_763b7_row3_col1 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_763b7_row3_col2 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_763b7_row3_col3 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_763b7_row4_col1 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_763b7_row4_col2 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_763b7_row4_col3 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_763b7_row5_col1 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_763b7_row5_col2 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_763b7_row5_col3 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_763b7_row6_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_763b7_row6_col2, #T_763b7_row11_col2 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_763b7_row6_col3 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_763b7_row7_col1 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_763b7_row7_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_763b7_row8_col1, #T_763b7_row26_col3 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_763b7_row8_col2, #T_763b7_row10_col1 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_763b7_row8_col3 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_763b7_row9_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_763b7_row9_col2, #T_763b7_row10_col2 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_763b7_row9_col3 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_763b7_row10_col3 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_763b7_row11_col1, #T_763b7_row12_col2, #T_763b7_row13_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_763b7_row11_col3, #T_763b7_row13_col3 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_763b7_row12_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_763b7_row12_col3, #T_763b7_row20_col3, #T_763b7_row24_col3 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_763b7_row13_col1 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_763b7_row14_col1 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_763b7_row14_col2 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_763b7_row14_col3 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_763b7_row15_col1 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_763b7_row15_col2 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_763b7_row15_col3 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_763b7_row16_col1, #T_763b7_row17_col1 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_763b7_row16_col2 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_763b7_row16_col3 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_763b7_row17_col2, #T_763b7_row20_col2 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_763b7_row17_col3, #T_763b7_row32_col3 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_763b7_row18_col1 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_763b7_row18_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_763b7_row18_col3, #T_763b7_row29_col3 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_763b7_row19_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_763b7_row19_col2, #T_763b7_row22_col2, #T_763b7_row27_col2, #T_763b7_row33_col2 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_763b7_row19_col3 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_763b7_row20_col1, #T_763b7_row21_col1 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_763b7_row21_col2, #T_763b7_row22_col1, #T_763b7_row23_col2, #T_763b7_row24_col2, #T_763b7_row29_col2 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_763b7_row21_col3, #T_763b7_row30_col3, #T_763b7_row34_col3, #T_763b7_row35_col3 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_763b7_row22_col3 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_763b7_row23_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_763b7_row23_col3 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_763b7_row24_col1, #T_763b7_row25_col1 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_763b7_row25_col2, #T_763b7_row26_col2, #T_763b7_row30_col1, #T_763b7_row30_col2, #T_763b7_row32_col2, #T_763b7_row37_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_763b7_row25_col3 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_763b7_row26_col1, #T_763b7_row27_col1, #T_763b7_row28_col1, #T_763b7_row29_col1 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_763b7_row27_col3 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_763b7_row28_col2 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_763b7_row28_col3 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_763b7_row31_col1, #T_763b7_row32_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_763b7_row31_col2, #T_763b7_row33_col1, #T_763b7_row34_col2, #T_763b7_row35_col2 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_763b7_row31_col3 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_763b7_row34_col1, #T_763b7_row35_col1, #T_763b7_row36_col1, #T_763b7_row37_col1 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_763b7_row36_col2, #T_763b7_row36_col3, #T_763b7_row38_col1, #T_763b7_row38_col2, #T_763b7_row38_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_763b7_row37_col3 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# </style>
# <table id="T_763b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_763b7_level0_col0" class="col_heading level0 col0" >venue</th>
#       <th id="T_763b7_level0_col1" class="col_heading level0 col1" >total_match</th>
#       <th id="T_763b7_level0_col2" class="col_heading level0 col2" >toss_winner_matches</th>
#       <th id="T_763b7_level0_col3" class="col_heading level0 col3" >toss_win_match_win_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_763b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_763b7_row0_col0" class="data row0 col0" >Wankhede Stadium</td>
#       <td id="T_763b7_row0_col1" class="data row0 col1" >118</td>
#       <td id="T_763b7_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_763b7_row0_col3" class="data row0 col3" >50.847458</td>
#     </tr>
#     <tr>
#       <th id="T_763b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_763b7_row1_col0" class="data row1 col0" >M Chinnaswamy Stadium</td>
#       <td id="T_763b7_row1_col1" class="data row1 col1" >94</td>
#       <td id="T_763b7_row1_col2" class="data row1 col2" >42</td>
#       <td id="T_763b7_row1_col3" class="data row1 col3" >44.680851</td>
#     </tr>
#     <tr>
#       <th id="T_763b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_763b7_row2_col0" class="data row2 col0" >Eden Gardens</td>
#       <td id="T_763b7_row2_col1" class="data row2 col1" >93</td>
#       <td id="T_763b7_row2_col2" class="data row2 col2" >47</td>
#       <td id="T_763b7_row2_col3" class="data row2 col3" >50.537634</td>
#     </tr>
#     <tr>
#       <th id="T_763b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_763b7_row3_col0" class="data row3 col0" >Arun Jaitley Stadium</td>
#       <td id="T_763b7_row3_col1" class="data row3 col1" >90</td>
#       <td id="T_763b7_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_763b7_row3_col3" class="data row3 col3" >32.222222</td>
#     </tr>
#     <tr>
#       <th id="T_763b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_763b7_row

# %% [markdown]
# #### *CONCLUSION --- FROM HERE WE CLEARLY SAW THAT IN Wankhede Stadium TOTAL MATCHED PLAYED 118 AND 60 MATCHES WON WHERE TEAM WIN THE TOSS, SO TOSS WIN MATCH WIN PERCENTAGE IN THIS STADIUM IS 50.84% WHICH IS HEIGHEST, AND SECOND HEIGHEST IS M Chinnaswamy Stadium 44.68%*

# %% [markdown]
# # **Q.6 --> TEAM'S WON THE TOURNAMENT**

# %%
winners_ipl=df2.groupby('season')['winner'].last().reset_index(name='team')

# %%
winners_ipl
# Out:
#      season                   team
# 0   2007/08       Rajasthan Royals
# 1      2009        Deccan Chargers
# 2   2009/10    Chennai Super Kings
# 3      2011    Chennai Super Kings
# 4      2012  Kolkata Knight Riders
# 5      2013         Mumbai Indians
# 6      2014  Kolkata Knight Riders
# 7      2015         Mumbai Indians
# 8      2016    Sunrisers Hyderabad
# 9      2017         Mumbai Indians
# 10     2018    Chennai Super Kings
# 11     2019         Mumbai Indians
# 12  2020/21         Mumbai Indians
# 13     2021    Chennai Super Kings
# 14     2022         Gujarat Titans
# 15     2023    Chennai Super Kings
# 16     2024  Kolkata Knight Riders

# %%
team_win=winners_ipl['team'].value_counts()

# %%
team_wins=team_win.reset_index()

# %%
team_wins.columns=['team','wins']

# %%
team_wins.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d9ffb_row0_col1, #T_d9ffb_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d9ffb_row2_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_d9ffb_row3_col1, #T_d9ffb_row4_col1, #T_d9ffb_row5_col1, #T_d9ffb_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d9ffb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9ffb_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_d9ffb_level0_col1" class="col_heading level0 col1" >wins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9ffb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9ffb_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_d9ffb_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9ffb_row1_col0" class="data row1 col0" >Mumbai Indians</td>
#       <td id="T_d9ffb_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9ffb_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_d9ffb_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9ffb_row3_col0" class="data row3 col0" >Rajasthan Royals</td>
#       <td id="T_d9ffb_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9ffb_row4_col0" class="data row4 col0" >Deccan Chargers</td>
#       <td id="T_d9ffb_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9ffb_row5_col0" class="data row5 col0" >Sunrisers Hyderabad</td>
#       <td id="T_d9ffb_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9ffb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9ffb_row6_col0" class="data row6 col0" >Gujarat Titans</td>
#       <td id="T_d9ffb_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
colors=['crimson']*2+['turquoise']*(len(team_wins)-1)
fig=go.Figure(
data=[
  go.Bar( x=team_wins['team'],y=team_wins['wins'],marker_color=colors,width=0.2)
])

fig.update_layout(

    title='IPL Winning Teams',
    xaxis_title='Team',
    yaxis_title='Win',
    bargap=0,
    width=600
)
fig.show()
# Out:
# <div>                            <div id="9742b96f-48d1-4a0c-bbbe-77e0378af03c" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9742b96f-48d1-4a0c-bbbe-77e0378af03c")) {                    Plotly.newPlot(                        "9742b96f-48d1-4a0c-bbbe-77e0378af03c",                        [{"marker":{"color":["crimson","crimson","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise"]},"width":0.2,"x":["Chennai Super Kings","Mumbai Indians","Kolkata Knight Riders","Rajasthan Royals","Deccan Chargers","Sunrisers Hyderabad","Gujarat Titans"],"y":[5,5,3,1,1,1,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %% [markdown]
# #### *CONCLUSION --- Chennai Super Kings WON THE MOST TOURAMENT TITLE 5 TIMES ALONG WITH THE Mumbai Indians, FOLLOWED BY Kolkata Knight Riders WITH 3 TROPHY*

# %% [markdown]
# # **Q.7 ---> FIND THE TOTAL MATCHS AND WIN MATCHES BY EACH TEAM**

# %% [markdown]
# #### *replace the values where it same such as  'Delhi Daredevils' and 'Delhi Capitals' both are same team they just change their name, 'Royal Challengers Bengaluru','Royal Challengers Bangalore' same team ....*

# %%
df2['winner']=df2['winner'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
df2['winner']=df2['winner'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df2['winner']=df2['winner'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')

# %%
df2['winner']=df2['winner'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
data=df2['winner'].value_counts()

# %%
win_match=data.drop('No Result')

# %%
win_match
# Out:
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    123
# Delhi Capitals                 115
# Rajasthan Royals               112
# Punjab Kings                   112
# Sunrisers Hyderabad             88
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Kochi Tuskers Kerala             6
# Name: winner, dtype: int64

# %%
df2[['team1', 'team2']] = df2[['team1', 'team2']].apply(lambda x: x.str.replace('Rising Pune Supergiants', 'Rising Pune Supergiant'))

# %%
df2[['team1','team2']]=df2[['team1','team2']].apply(lambda x: x.str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore'))

# %%
df2[['team1','team2']]=df2[['team1','team2']].apply(lambda x: x.str.replace('Delhi Daredevils','Delhi Capitals'))

# %%
df2[['team1','team2']]=df2[['team1','team2']].apply(lambda x: x.str.replace('Kings XI Punjab','Punjab Kings'))

# %%
team=pd.concat([df2['team1'],df2['team2']])

# %%
total_matches = team.value_counts()

# %%
total_matches
# Out:
# Mumbai Indians                 261
# Royal Challengers Bangalore    255
# Delhi Capitals                 252
# Kolkata Knight Riders          251
# Punjab Kings                   246
# Chennai Super Kings            238
# Rajasthan Royals               221
# Sunrisers Hyderabad            182
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Titans                  45
# Lucknow Super Giants            44
# Gujarat Lions                   30
# Rising Pune Supergiant          30
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
team_played=pd.DataFrame(
{
    'Team':total_matches.index,
    'Total_Match':total_matches.values,
    'win_match':win_match.values
    
}
)

# %%
team_played.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_410ec_row0_col1, #T_410ec_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_410ec_row1_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_410ec_row1_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_410ec_row2_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_410ec_row2_col2 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_410ec_row3_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_410ec_row3_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_410ec_row4_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_410ec_row4_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_410ec_row5_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_410ec_row5_col2, #T_410ec_row6_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_410ec_row6_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_410ec_row7_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_410ec_row7_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_410ec_row8_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_410ec_row8_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_410ec_row9_col1, #T_410ec_row10_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_410ec_row9_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_410ec_row10_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_410ec_row11_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_410ec_row11_col2, #T_410ec_row12_col1, #T_410ec_row13_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_410ec_row12_col2, #T_410ec_row13_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_410ec_row14_col1, #T_410ec_row14_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_410ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_410ec_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_410ec_level0_col1" class="col_heading level0 col1" >Total_Match</th>
#       <th id="T_410ec_level0_col2" class="col_heading level0 col2" >win_match</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_410ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_410ec_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_410ec_row0_col1" class="data row0 col1" >261</td>
#       <td id="T_410ec_row0_col2" class="data row0 col2" >144</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_410ec_row1_col0" class="data row1 col0" >Royal Challengers Bangalore</td>
#       <td id="T_410ec_row1_col1" class="data row1 col1" >255</td>
#       <td id="T_410ec_row1_col2" class="data row1 col2" >138</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_410ec_row2_col0" class="data row2 col0" >Delhi Capitals</td>
#       <td id="T_410ec_row2_col1" class="data row2 col1" >252</td>
#       <td id="T_410ec_row2_col2" class="data row2 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_410ec_row3_col0" class="data row3 col0" >Kolkata Knight Riders</td>
#       <td id="T_410ec_row3_col1" class="data row3 col1" >251</td>
#       <td id="T_410ec_row3_col2" class="data row3 col2" >123</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_410ec_row4_col0" class="data row4 col0" >Punjab Kings</td>
#       <td id="T_410ec_row4_col1" class="data row4 col1" >246</td>
#       <td id="T_410ec_row4_col2" class="data row4 col2" >115</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_410ec_row5_col0" class="data row5 col0" >Chennai Super Kings</td>
#       <td id="T_410ec_row5_col1" class="data row5 col1" >238</td>
#       <td id="T_410ec_row5_col2" class="data row5 col2" >112</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_410ec_row6_col0" class="data row6 col0" >Rajasthan Royals</td>
#       <td id="T_410ec_row6_col1" class="data row6 col1" >221</td>
#       <td id="T_410ec_row6_col2" class="data row6 col2" >112</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_410ec_row7_col0" class="data row7 col0" >Sunrisers Hyderabad</td>
#       <td id="T_410ec_row7_col1" class="data row7 col1" >182</td>
#       <td id="T_410ec_row7_col2" class="data row7 col2" >88</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_410ec_row8_col0" class="data row8 col0" >Deccan Chargers</td>
#       <td id="T_410ec_row8_col1" class="data row8 col1" >75</td>
#       <td id="T_410ec_row8_col2" class="data row8 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_410ec_row9_col0" class="data row9 col0" >Pune Warriors</td>
#       <td id="T_410ec_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_410ec_row9_col2" class="data row9 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_410ec_row10_col0" class="data row10 col0" >Gujarat Titans</td>
#       <td id="T_410ec_row10_col1" class="data row10 col1" >45</td>
#       <td id="T_410ec_row10_col2" class="data row10 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_410ec_row11_col0" class="data row11 col0" >Lucknow Super Giants</td>
#       <td id="T_410ec_row11_col1" class="data row11 col1" >44</td>
#       <td id="T_410ec_row11_col2" class="data row11 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_410ec_row12_col0" class="data row12 col0" >Gujarat Lions</td>
#       <td id="T_410ec_row12_col1" class="data row12 col1" >30</td>
#       <td id="T_410ec_row12_col2" class="data row12 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_410ec_row13_col0" class="data row13 col0" >Rising Pune Supergiant</td>
#       <td id="T_410ec_row13_col1" class="data row13 col1" >30</td>
#       <td id="T_410ec_row13_col2" class="data row13 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_410ec_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_410ec_row14_col0" class="data row14 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_410ec_row14_col1" class="data row14 col1" >14</td>
#       <td id="T_410ec_row14_col2" class="data row14 col2" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
team_w=team_played.head(12)

# %%
melted_df=team_w.melt(id_vars="Team",var_name="Match Type",value_name="Count")

# %%
fig=px.bar(

    melted_df,
    x="Team",
    y="Count",
    color="Match Type",
     title="TOTAL MATCHES VS WINS FOR EACH TEAM",
    barmode="group",
    labels={"Count": "Number of Matches", "Team": "IPL Teams"},
    height=500,
    width=700
    
)
fig.show()

# %% [markdown]
# #### *CONCLUSION --- Mumbai Indians PLAYED 261 MATCHES AND  WON 144 MATCHES, Royal Challengers Bangalore	PLAYED 255 MATCHES AND WON  138 MATCHES...Delhi Capitals(252) and  Kolkata Knight Riders(251) both played 250+ matches*

# %% [markdown]
# # **Q.8 ---> LUCKY VENUE FOR A TEAM**

# %%
df2['team1'].value_counts()
# Out:
# Royal Challengers Bangalore    144
# Chennai Super Kings            128
# Delhi Capitals                 126
# Punjab Kings                   123
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Sunrisers Hyderabad             86
# Deccan Chargers                 39
# Pune Warriors                   23
# Lucknow Super Giants            23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Kochi Tuskers Kerala             7
# Name: team1, dtype: int64

# %%
def Lucky(match_data,team_name):
    return match_data[match_data['winner']==team_name]['venue'].value_counts().nlargest(10)

# %%
rcb=Lucky(df2,'Royal Challengers Bangalore')
values=rcb
labels=rcb.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="73f7fc2d-0901-46af-9480-ef5e22344c01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73f7fc2d-0901-46af-9480-ef5e22344c01")) {                    Plotly.newPlot(                        "73f7fc2d-0901-46af-9480-ef5e22344c01",                        [{"hole":0.2,"labels":["M Chinnaswamy Stadium","Wankhede Stadium","Dubai International Cricket Stadium","Arun Jaitley Stadium","Eden Gardens","MA Chidambaram Stadium","Punjab Cricket Association IS Bindra Stadium","Maharashtra Cricket Association Stadium","Rajiv Gandhi International Stadium","Sawai Mansingh Stadium"],"values":[44,8,8,6,5,5,5,4,4,4],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tic ...
#
# var

# %%
mi=Lucky(df2,'Mumbai Indians')
values=mi
labels=mi.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="e863b4ef-ea87-4204-8756-f0e6dd53ebdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e863b4ef-ea87-4204-8756-f0e6dd53ebdb")) {                    Plotly.newPlot(                        "e863b4ef-ea87-4204-8756-f0e6dd53ebdb",                        [{"hole":0.2,"labels":["Wankhede Stadium","Eden Gardens","M Chinnaswamy Stadium","MA Chidambaram Stadium","Rajiv Gandhi International Stadium","Brabourne Stadium","Arun Jaitley Stadium","Sheikh Zayed Stadium","Dr DY Patil Sports Academy","Punjab Cricket Association IS Bindra Stadium"],"values":[52,10,9,8,8,7,7,6,6,5],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"typ ...
#
# var gd = document.getElementById('e8

# %%
csk=Lucky(df2,'Chennai Super Kings')
values=csk
labels=csk.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="f96969d7-60ca-484c-a9d5-8e394c1c29d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f96969d7-60ca-484c-a9d5-8e394c1c29d0")) {                    Plotly.newPlot(                        "f96969d7-60ca-484c-a9d5-8e394c1c29d0",                        [{"hole":0.2,"labels":["MA Chidambaram Stadium","Wankhede Stadium","Dubai International Cricket Stadium","Arun Jaitley Stadium","M Chinnaswamy Stadium","Eden Gardens","Maharashtra Cricket Association Stadium","Dr DY Patil Sports Academy","Punjab Cricket Association IS Bindra Stadium","Sawai Mansingh Stadium"],"values":[50,13,9,8,6,6,6,6,3,3],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...
#
# var gd = do

# %%
dc=Lucky(df2,'Delhi Capitals')
values=dc
labels=dc.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="38ae2ee8-4797-4115-8ef7-6dd328137b9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38ae2ee8-4797-4115-8ef7-6dd328137b9c")) {                    Plotly.newPlot(                        "38ae2ee8-4797-4115-8ef7-6dd328137b9c",                        [{"hole":0.2,"labels":["Arun Jaitley Stadium","Dubai International Cricket Stadium","Rajiv Gandhi International Stadium","Wankhede Stadium","Sharjah Cricket Stadium","MA Chidambaram Stadium","Brabourne Stadium","Shaheed Veer Narayan Singh International Stadium","Narendra Modi Stadium, Ahmedabad","M Chinnaswamy Stadium"],"values":[37,7,6,6,5,4,4,4,4,4],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0," ...
#
# v

# %%
pk=Lucky(df2,'Punjab Kings')
values=pk
labels=pk.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="a0506407-0fda-45db-9bc3-dc11a9a3cfe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0506407-0fda-45db-9bc3-dc11a9a3cfe6")) {                    Plotly.newPlot(                        "a0506407-0fda-45db-9bc3-dc11a9a3cfe6",                        [{"hole":0.2,"labels":["Punjab Cricket Association IS Bindra Stadium","Wankhede Stadium","Dubai International Cricket Stadium","Arun Jaitley Stadium","Himachal Pradesh Cricket Association Stadium","Sharjah Cricket Stadium","MA Chidambaram Stadium","M Chinnaswamy Stadium","Eden Gardens","Holkar Cricket Stadium"],"values":[31,9,7,6,5,5,5,5,4,4],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...
#
# var gd = d

# %%
k=Lucky(df2,'Kolkata Knight Riders')
values=k
labels=k.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="e8b26f2c-ba29-46a3-9150-04355bb9a561" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8b26f2c-ba29-46a3-9150-04355bb9a561")) {                    Plotly.newPlot(                        "e8b26f2c-ba29-46a3-9150-04355bb9a561",                        [{"hole":0.2,"labels":["Eden Gardens","M Chinnaswamy Stadium","Rajiv Gandhi International Stadium","Sheikh Zayed Stadium","Maharashtra Cricket Association Stadium","Sharjah Cricket Stadium","Arun Jaitley Stadium","MA Chidambaram Stadium","Wankhede Stadium","Punjab Cricket Association IS Bindra Stadium"],"values":[52,10,6,6,5,5,5,5,5,4],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...
#
# var gd = document

# %%
rr=Lucky(df2,'Rajasthan Royals')
values=rr
labels=rr.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="f425c610-331c-4209-8ada-2beceec84603" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f425c610-331c-4209-8ada-2beceec84603")) {                    Plotly.newPlot(                        "f425c610-331c-4209-8ada-2beceec84603",                        [{"hole":0.2,"labels":["Sawai Mansingh Stadium","Wankhede Stadium","Sardar Patel Stadium, Motera","Sheikh Zayed Stadium","Brabourne Stadium","Arun Jaitley Stadium","Eden Gardens","M Chinnaswamy Stadium","Rajiv Gandhi International Stadium","Narendra Modi Stadium, Ahmedabad"],"values":[37,10,7,6,5,5,4,4,3,3],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatte ...
#
# var gd = document.getElementById('f425c610-331

# %%
lsg=Lucky(df2,'Lucknow Super Giants')
values=lsg
labels=lsg.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="1b9fbdfd-85df-4f9b-b25c-1b2ba2ff7adb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b9fbdfd-85df-4f9b-b25c-1b2ba2ff7adb")) {                    Plotly.newPlot(                        "1b9fbdfd-85df-4f9b-b25c-1b2ba2ff7adb",                        [{"hole":0.2,"labels":["Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow","Dr DY Patil Sports Academy","Wankhede Stadium","Brabourne Stadium","Maharashtra Cricket Association Stadium","M Chinnaswamy Stadium","Sawai Mansingh Stadium","Punjab Cricket Association IS Bindra Stadium","Rajiv Gandhi International Stadium","Eden Gardens"],"values":[7,3,3,2,2,2,1,1,1,1],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker": ...

# %%
gt=Lucky(df2,'Gujarat Titans')
values=gt
labels=gt.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="cc67f5b3-0530-4b7b-9503-cb7e07555c31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc67f5b3-0530-4b7b-9503-cb7e07555c31")) {                    Plotly.newPlot(                        "cc67f5b3-0530-4b7b-9503-cb7e07555c31",                        [{"hole":0.2,"labels":["Narendra Modi Stadium, Ahmedabad","Wankhede Stadium","Maharashtra Cricket Association Stadium","Brabourne Stadium","Dr DY Patil Sports Academy","Eden Gardens","Sawai Mansingh Stadium","Arun Jaitley Stadium","Punjab Cricket Association IS Bindra Stadium","Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow"],"values":[9,3,3,2,2,2,2,1,1,1],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"c ...

# %%
srh=Lucky(df2,'Sunrisers Hyderabad')
values=srh
labels=srh.index
colors = ['turquoise', 'crimson']
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=.2)])
fig.update_traces(hoverinfo='label+percent',textinfo='value')
fig.show()
# Out:
# <div>                            <div id="a294d3b6-f26f-4f2b-9171-3f795cbfe7e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a294d3b6-f26f-4f2b-9171-3f795cbfe7e0")) {                    Plotly.newPlot(                        "a294d3b6-f26f-4f2b-9171-3f795cbfe7e0",                        [{"hole":0.2,"labels":["Rajiv Gandhi International Stadium","Arun Jaitley Stadium","Dubai International Cricket Stadium","Punjab Cricket Association IS Bindra Stadium","Dr DY Patil Sports Academy","M Chinnaswamy Stadium","Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium","Brabourne Stadium","Eden Gardens","Sawai Mansingh Stadium"],"values":[36,8,7,4,3,3,3,3,3,2],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %% [markdown]
# ### CONCLUSION --- FROM HERE WE CAN COLCLUDE THAT EACH TEAMS FAVOURITE VENUE IS THEIR HOME GROUND

# %% [markdown]
# # **Q.9 ---> FIND OUT EACH TEAM FIGHT HEAD TO HEAD**

# %% [markdown]
# #### *HERE WE COMPARE TEAM RCB WITH SOME OF other OPPONENT*

# %%
def comparison (team1,team2):
    compare=df2[((df2['team1']==team1) | (df2['team2']==team1))   &  ((df2['team1']==team2) | (df2['team2']==team2))]
    group_data=compare.groupby('winner').size().reset_index(name='Match Win')
    fig=px.pie(group_data,names='winner',values='Match Win')
    fig.show()

# %%
comparison('Royal Challengers Bangalore','Mumbai Indians')
# Out:
# <div>                            <div id="581ee65c-d5b4-40e6-8720-75d93b9afc35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("581ee65c-d5b4-40e6-8720-75d93b9afc35")) {                    Plotly.newPlot(                        "581ee65c-d5b4-40e6-8720-75d93b9afc35",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"winner=%{label}\u003cbr\u003eMatch Win=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Mumbai Indians","Royal Challengers Bangalore"],"legendgroup":"","name":"","showlegend":true,"values":[19,14],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...
#
# var gd = document.getElementById('581ee65c-d5b4-40e6-8720-75d93b9afc35');
# var x = new Mu

# %%
comparison('Royal Challengers Bangalore','Chennai Super Kings')
# Out:
# <div>                            <div id="409acb15-bf1e-406d-a39b-a6855fc41bed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("409acb15-bf1e-406d-a39b-a6855fc41bed")) {                    Plotly.newPlot(                        "409acb15-bf1e-406d-a39b-a6855fc41bed",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"winner=%{label}\u003cbr\u003eMatch Win=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Chennai Super Kings","Royal Challengers Bangalore"],"legendgroup":"","name":"","showlegend":true,"values":[21,11],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker" ...
#
# var gd = document.getElementById('409acb15-bf1e-406d-a39b-a6855fc41bed');
# var x = n

# %%
comparison('Royal Challengers Bangalore','Kolkata Knight Riders')
# Out:
# <div>                            <div id="ede275ce-8a3a-42d3-9110-e5de236fadac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ede275ce-8a3a-42d3-9110-e5de236fadac")) {                    Plotly.newPlot(                        "ede275ce-8a3a-42d3-9110-e5de236fadac",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"winner=%{label}\u003cbr\u003eMatch Win=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Kolkata Knight Riders","Royal Challengers Bangalore"],"legendgroup":"","name":"","showlegend":true,"values":[20,14],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marke ...
#
# var gd = document.getElementById('ede275ce-8a3a-42d3-9110-e5de236fadac');
# var x =

# %% [markdown]
# # **Q.10 ---> TOP 5 PLAYERS WITH HIGHEST RUNS**

# %%
df1['batting_team']=df1['batting_team'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
df1['batting_team']=df1['batting_team'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df1['batting_team']=df1['batting_team'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')

# %%
df1['batting_team']=df1['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df1['bowling_team']=df1['bowling_team'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
df1['bowling_team']=df1['bowling_team'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df1['bowling_team']=df1['bowling_team'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')

# %%
df1['bowling_team']=df1['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df1['batting_team'].value_counts()
# Out:
# Mumbai Indians                 31437
# Royal Challengers Bangalore    30023
# Delhi Capitals                 29732
# Kolkata Knight Riders          29514
# Punjab Kings                   29479
# Chennai Super Kings            28651
# Rajasthan Royals               26242
# Sunrisers Hyderabad            21843
# Deccan Chargers                 9034
# Gujarat Titans                  5494
# Pune Warriors                   5443
# Lucknow Super Giants            5400
# Gujarat Lions                   3566
# Rising Pune Supergiant          3480
# Kochi Tuskers Kerala            1582
# Name: batting_team, dtype: int64

# %%
top5=df1.groupby('batter',as_index=False)['batsman_runs'].sum().sort_values(by='batsman_runs',ascending=False).head(5)

# %%
top5 = top5.reset_index(drop=True)
top5.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_12c8d_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_12c8d_row1_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_12c8d_row2_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_12c8d_row3_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_12c8d_row4_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_12c8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12c8d_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_12c8d_level0_col1" class="col_heading level0 col1" >batsman_runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12c8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12c8d_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_12c8d_row0_col1" class="data row0 col1" >8014</td>
#     </tr>
#     <tr>
#       <th id="T_12c8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12c8d_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_12c8d_row1_col1" class="data row1 col1" >6769</td>
#     </tr>
#     <tr>
#       <th id="T_12c8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12c8d_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_12c8d_row2_col1" class="data row2 col1" >6630</td>
#     </tr>
#     <tr>
#       <th id="T_12c8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12c8d_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_12c8d_row3_col1" class="data row3 col1" >6567</td>
#     </tr>
#     <tr>
#       <th id="T_12c8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12c8d_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_12c8d_row4_col1" class="data row4 col1" >5536</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### *KING KHOLI COMES WITH THE HIGHEST RUN SCORERS*

# %% [markdown]
# # **Q.11 ---> INDIVIDUAL PLAYES PERFROMANCE ANALYSIS HERE I ANALYSIS VIRAT,S PERFORMANCE**

# %% [markdown]
# ## **Q.11A --> KOHLI'S RUN ANALYSIS**

# %%
virat=df1[df1['batter']=='V Kohli']

# %%
def run(df,runs):
    return len(df[df['batsman_runs']==runs])*runs

# %%
print(f"virat scored {run(virat,1)} by taking 1's ")
print(f"virat scored {run(virat,2)} by taking 2's ")
print(f"virat scored {run(virat,3)} by taking 3's ")
print(f"virat scored {run(virat,4)} by taking 4's ")
print(f"virat scored {run(virat,6)} by taking 6's ")
# Out:
# virat scored 2591 by taking 1's
# virat scored 890 by taking 2's
# virat scored 63 by taking 3's
# virat scored 2832 by taking 4's
# virat scored 1638 by taking 6's

# %%
total_runs=[2591,890,63,2832,1638]
shorts=[1,2,3,4,6]
fig=px.pie(values=total_runs,names=shorts)
fig.show()
# Out:
# <div>                            <div id="1a110687-03b7-467c-8eb9-14035f5bf8c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a110687-03b7-467c-8eb9-14035f5bf8c9")) {                    Plotly.newPlot(                        "1a110687-03b7-467c-8eb9-14035f5bf8c9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[1,2,3,4,6],"legendgroup":"","name":"","showlegend":true,"values":[2591,890,63,2832,1638],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overla ...
#
# var gd = document.getElementById('1a110687-03b7-467c-8eb9-14035f5bf8c9');
# var x = new MutationObserver(function (m

# %% [markdown]
# #### *VIRAT KOHLI RUN ANALYSIS HE SCORED scored 2591 by taking 1's (32.3%) , virat scored 890 by taking 2's(11.1%) ,HE scored 63 by taking 3's ,virat scored 2832 by taking 4's (35.3%) AND scored 1638 by taking 6's (20.4%),**KING** LOVES TO TAKE SINGLE ALSO HE LOVE TO HIT 4'S*

# %% [markdown]
# ## **Q.11B --> KHOLI'S DISMISSAL ANALYSIS**

# %%
values=virat['dismissal_kind'].value_counts()
labels=virat['dismissal_kind'].value_counts().index
fig=go.Figure(data=[go.Pie(labels=labels,values=values,hole=0.3)]
             )
fig.update_traces(hoverinfo='label+percent',textinfo='label')
fig.update_layout(title='Virat dismissal in ipl')
fig.show()
# Out:
# <div>                            <div id="bad59bb1-bcb0-48ac-9276-4dbad1ee87dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bad59bb1-bcb0-48ac-9276-4dbad1ee87dc")) {                    Plotly.newPlot(                        "bad59bb1-bcb0-48ac-9276-4dbad1ee87dc",                        [{"hole":0.3,"labels":["caught","bowled","run out","lbw","stumped","caught and bowled"],"values":[138,39,20,12,5,4],"type":"pie","hoverinfo":"label+percent","textinfo":"label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scatt ...
#
# var gd = document.getElementById('bad59bb1-bcb0-48ac-9276-4dbad1ee87dc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;

# %% [markdown]
# #### *MOST OF THE TIME HE CAUGHT OUT  (63.3%) FOLLOWED BY BOWLED OUT(17.9%)*

# %% [markdown]
# ## **Q.11C --> WHO TAKES KOHLI'S WICKET MOST OF THE TIME**

# %%
wicket_df=virat[virat['is_wicket']==1]

# %%
wicket=wicket_df.groupby('bowler').size().sort_values(ascending=False).head(5).reset_index(name='taken')

# %% [markdown]
# wicket.style.background_gradient(cmap='Blues')

# %% [markdown]
# #### *7 TIMES Sandeep Sharma SEND HIM  TO THE PAVILION ,FOLLOWED BY ASHISH NEHRA 6 TIMES*

# %% [markdown]
# ## **Q.11D --> KOHLI'S FIRST AND SEOCEND INNINGS COMPARISION**

# %%
virat['inning'].value_counts()
# Out:
# 1    3473
# 2    2759
# 4       4
# Name: inning, dtype: int64

# %%
virat = virat.copy()  # Make sure virat is a copy, not a view
virat['inning'] = virat['inning'].replace(4, 2)

# %%
virat['inning'].value_counts()
# Out:
# 1    3473
# 2    2763
# Name: inning, dtype: int64

# %%
virat_inning=virat.groupby('inning')['batsman_runs'].sum().reset_index(name='run')

# %%
virat_inning
# Out:
#    inning   run
# 0       1  4400
# 1       2  3614

# %%
fig=px.bar(

    virat_inning,
    x="inning",
    y="run",
    
     title="1st vs 2nd innings ",
width=400, 
    height=400,
    
   
    labels={"run": "Total Run", "inning": "Innings"}
    
)
fig.update_layout(bargap=.7,
                 template='simple_white')
fig.show()
# Out:
# <div>                            <div id="1da179fb-7ad3-4f1d-a5d7-5c9673173b6b" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1da179fb-7ad3-4f1d-a5d7-5c9673173b6b")) {                    Plotly.newPlot(                        "1da179fb-7ad3-4f1d-a5d7-5c9673173b6b",                        [{"alignmentgroup":"True","hovertemplate":"Innings=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2],"xaxis":"x","y":[4400,3614],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","tick ...

# %% [markdown]
# ### *IN INNINGS 2 HE SCORED 3614 RUNS ALMOST HALF OF HIS ENTIRE RUN ,A ABSOLUTE CHASE MASTER*

# %% [markdown]
# ## **Q.11E --> KOHLI'S RUNS AGAINST EACH TEAM**

# %%
runs=virat.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).reset_index(name='run').head(5)

# %%
runs
# Out:
#             bowling_team   run
# 0         Delhi Capitals  1057
# 1    Chennai Super Kings  1053
# 2           Punjab Kings  1030
# 3  Kolkata Knight Riders   962
# 4         Mumbai Indians   860

# %%
fig=px.bar(

    runs,
    x="bowling_team",
    y="run",
    
     title="RUN againest different Team",
width=600, 
    height=400,
    color="bowling_team",
   
    labels={"run": "Total Run", "bowling_team": "RUN againest different team"}
    
)
fig.update_layout(bargap=.7)
fig.show()
# Out:
# <div>                            <div id="78894359-2a54-4917-86dc-1844f2621f25" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78894359-2a54-4917-86dc-1844f2621f25")) {                    Plotly.newPlot(                        "78894359-2a54-4917-86dc-1844f2621f25",                        [{"alignmentgroup":"True","hovertemplate":"RUN againest different team=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi Capitals","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Delhi Capitals","offsetgroup":"Delhi Capitals","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi Capitals"],"xaxis":"x","y":[1057],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN againest different team=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai Super Kings","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chennai Super Kings","offsetgroup":"Chennai Super Kings","orientation":"v","showlegend":true,"textposition":"auto","x":["Chennai Super Kings"],"xaxis":"x","y":[1053],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN againest different team=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Punjab Kings","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Punjab Kings","offsetgroup":"Punjab Kings","orientation":"v","showlegend":true,"textposition":"auto","x":["Punjab Kings"],"xaxis":"x","y":[1030],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN againest different team=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata Knight Riders","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Kolkata Knight Riders","offsetgroup":"Kolkata Knight Riders","orientation":"v","showlegend":true,"textposition":"auto","x":["Kolkata Knight Riders"],"xaxis":"x","y":[962],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN againest different team=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mumbai Indians","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mumbai Indians","offsetgroup":"Mumbai Indians","orientation":"v","showlegend":true,"textposition":"auto","x":["Mumbai Indians"],"xaxis":"x","y":[860],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %% [markdown]
# ### *FROM THIS WE CAN SAY THAT HIS FAVOURITE OPPONENTS ARE Delhi Capitals (1057 RUNS) , Chennai Super Kings (1053 RUNS), Punjab Kings (1030 RUNS)*

# %% [markdown]
# ## **Q.11F --> HIS FAVOURITE VENUE**

# %%
stadium_data_virat=df2[['id','season','venue']].merge(virat,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
stadium_data=stadium_data_virat.groupby('venue')['batsman_runs'].sum().sort_values(ascending=False).reset_index(name='run').head(5)

# %%
stadium_data
# Out:
#                                 venue     run
# 0               M Chinnaswamy Stadium  3040.0
# 1                    Wankhede Stadium   574.0
# 2  Rajiv Gandhi International Stadium   491.0
# 3                Arun Jaitley Stadium   483.0
# 4              MA Chidambaram Stadium   383.0

# %%
fig=px.bar(

    stadium_data,
    x="venue",
    y="run",
    
     title="RUN in different stadium",
width=600, 
    height=400,
    color="venue",
   
    labels={"run": "Total Run", "venue": "RUN in different venue"}
    
)
fig.update_layout(bargap=.7,
                 showlegend=False)
fig.show()
# Out:
# <div>                            <div id="b5e2855c-6296-4a1b-b83b-2c1d15241e4f" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5e2855c-6296-4a1b-b83b-2c1d15241e4f")) {                    Plotly.newPlot(                        "b5e2855c-6296-4a1b-b83b-2c1d15241e4f",                        [{"alignmentgroup":"True","hovertemplate":"RUN in different venue=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M Chinnaswamy Stadium","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M Chinnaswamy Stadium","offsetgroup":"M Chinnaswamy Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["M Chinnaswamy Stadium"],"xaxis":"x","y":[3040.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN in different venue=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wankhede Stadium","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wankhede Stadium","offsetgroup":"Wankhede Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Wankhede Stadium"],"xaxis":"x","y":[574.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN in different venue=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rajiv Gandhi International Stadium","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Rajiv Gandhi International Stadium","offsetgroup":"Rajiv Gandhi International Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Rajiv Gandhi International Stadium"],"xaxis":"x","y":[491.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN in different venue=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arun Jaitley Stadium","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Arun Jaitley Stadium","offsetgroup":"Arun Jaitley Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Arun Jaitley Stadium"],"xaxis":"x","y":[483.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RUN in different venue=%{x}\u003cbr\u003eTotal Run=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MA Chidambaram Stadium","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"MA Chidambaram Stadium","offsetgroup":"MA Chidambaram Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["MA Chidambaram Stadium"],"xaxis":"x","y":[383.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}], ...

# %% [markdown]
# ### *OF COURSE M Chinnaswamy Stadium WITH	3040 RUNS*

# %% [markdown]
# ## **Q.11G --> KING'S RUNS BY EACH SEASON**

# %%
data_virat=df2[['id','season','venue']].merge(virat,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
runs_trend=data_virat.groupby('season',as_index=False)['batsman_runs'].sum().sort_values(by='season')

# %%
runs_trend['batsman_runs'] = runs_trend['batsman_runs'].astype(int)
runs_trend
# Out:
#      season  batsman_runs
# 0   2007/08           165
# 1      2009           246
# 2   2009/10           307
# 3      2011           557
# 4      2012           364
# 5      2013           639
# 6      2014           359
# 7      2015           505
# 8      2016           973
# 9      2017           308
# 10     2018           530
# 11     2019           464
# 12  2020/21           471
# 13     2021           405
# 14     2022           341
# 15     2023           639
# 16     2024           741

# %%
fig=go.Figure()
fig.add_trace(
    go.Scatter(
        x=runs_trend['season'],
        y=runs_trend['batsman_runs'],
        mode='lines+markers'
    )

)

fig.update_layout(
    xaxis_title='season',
    yaxis_title='total_runs',
    title='total run in each ipl season',
    template='simple_white'
)

fig.show()
# Out:
# <div>                            <div id="3b05c48e-1f9f-4156-8225-1de098b31a0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b05c48e-1f9f-4156-8225-1de098b31a0b")) {                    Plotly.newPlot(                        "3b05c48e-1f9f-4156-8225-1de098b31a0b",                        [{"mode":"lines+markers","x":["2007\u002f08","2009","2009\u002f10","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020\u002f21","2021","2022","2023","2024"],"y":[165,246,307,557,364,639,359,505,973,308,530,464,471,405,341,639,741],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth ...

# %% [markdown]
# ### *CONCLUSION --- KING'S PICK YEAR WAS 2016 WITH 973 RECORD BRACKING RUN BUT AFTER THAT THERE WAS A DOWNFALL, BUT THEN THE LAST TWO YEARS HE CAME BACK SUPREMLY 2023 WITH 639 RUNS ,2024 WITH 741 RUNS, ORANGE CUP WINNER*

# %% [markdown]
# # **Q.12 ---> HIGHEST WICKET TAKER**

# %%
df1['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field', 'retired out'], dtype=object)

# %%
dismissal_kinds=['caught', 'bowled','lbw','stumped', 'caught and bowled', 'hit wicket']

# %%
bowl=df1[df1['dismissal_kind'] .isin (dismissal_kinds)]

# %%
hwtb=bowl['bowler'].value_counts().reset_index().head(10)

# %%
hwtb.columns=['bowler','wicket']
hwtb
# Out:
#        bowler  wicket
# 0   YS Chahal     205
# 1   PP Chawla     192
# 2    DJ Bravo     183
# 3     B Kumar     181
# 4   SP Narine     180
# 5    R Ashwin     180
# 6    A Mishra     174
# 7  SL Malinga     170
# 8   JJ Bumrah     168
# 9   RA Jadeja     160

# %%
colors=['crimson']+['turquoise']*(len(hwtb)-1)
fig=go.Figure(
data=[
  go.Bar( x=hwtb['bowler'],y=hwtb['wicket'],marker_color=colors,width=0.2)
])

fig.update_layout(

    title='Highest wicket taker',
    xaxis_title='Bowler',
    yaxis_title='Total Wicket',
    bargap=.9,
    width=600,
    template='simple_white'
    
)
fig.show()
# Out:
# <div>                            <div id="36e83a36-84a9-4e1d-a8b6-35501b010daa" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36e83a36-84a9-4e1d-a8b6-35501b010daa")) {                    Plotly.newPlot(                        "36e83a36-84a9-4e1d-a8b6-35501b010daa",                        [{"marker":{"color":["crimson","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise"]},"width":0.2,"x":["YS Chahal","PP Chawla","DJ Bravo","B Kumar","SP Narine","R Ashwin","A Mishra","SL Malinga","JJ Bumrah","RA Jadeja"],"y":[205,192,183,181,180,180,174,170,168,160],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outsi ...

# %% [markdown]
# ### *CONCLUSION --- YS Chahal HOLDS THE HIGHEST WICKET TAKER WITH 205 WICKET, FOLLOWED PP Chawla WITH 192 WICKET*

# %% [markdown]
# # **Q.13 ---> INDIVIDUAL BOWLER PERFROMANCE ANALYSIS . I CHOOSE YS Chahal**

# %% [markdown]
# ### **DISMISSAL TYPE**

# %%
dismissal_kinds=['caught', 'bowled','lbw','stumped', 'caught and bowled', 'hit wicket']

# %%
bowl=df1[df1['dismissal_kind'] .isin (dismissal_kinds)]

# %%
chahal=bowl[bowl['bowler']=='YS Chahal']

# %%
c=chahal.groupby('dismissal_kind')['is_wicket'].sum().sort_values(ascending=False).reset_index(name='wicket')

# %%
c.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_a36ff_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_a36ff_row1_col1 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_a36ff_row2_col1 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_a36ff_row3_col1 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_a36ff_row4_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_a36ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a36ff_level0_col0" class="col_heading level0 col0" >dismissal_kind</th>
#       <th id="T_a36ff_level0_col1" class="col_heading level0 col1" >wicket</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a36ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a36ff_row0_col0" class="data row0 col0" >caught</td>
#       <td id="T_a36ff_row0_col1" class="data row0 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_a36ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a36ff_row1_col0" class="data row1 col0" >bowled</td>
#       <td id="T_a36ff_row1_col1" class="data row1 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_a36ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a36ff_row2_col0" class="data row2 col0" >stumped</td>
#       <td id="T_a36ff_row2_col1" class="data row2 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_a36ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a36ff_row3_col0" class="data row3 col0" >lbw</td>
#       <td id="T_a36ff_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a36ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a36ff_row4_col0" class="data row4 col0" >caught and bowled</td>
#       <td id="T_a36ff_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### CONCLUSION --- MOST NUMBER OF TIME ,127 TIMES HE TOOK WICKET BY CAUGHT

# %% [markdown]
# ### **FAVOURITE VENUE**

# %%
data_chahal=df2[['id','season','venue']].merge(chahal,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
cw=data_chahal.groupby('venue')['is_wicket'].sum().sort_values(ascending=False).reset_index(name='wicket').head(5)

# %%
cw['wicket'] = cw['wicket'].astype(int)

# %%
cw.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_951ca_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_951ca_row1_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_951ca_row2_col1 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_951ca_row3_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_951ca_row4_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_951ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_951ca_level0_col0" class="col_heading level0 col0" >venue</th>
#       <th id="T_951ca_level0_col1" class="col_heading level0 col1" >wicket</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_951ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_951ca_row0_col0" class="data row0 col0" >M Chinnaswamy Stadium</td>
#       <td id="T_951ca_row0_col1" class="data row0 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_951ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_951ca_row1_col0" class="data row1 col0" >Wankhede Stadium</td>
#       <td id="T_951ca_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_951ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_951ca_row2_col0" class="data row2 col0" >Dubai International Cricket Stadium</td>
#       <td id="T_951ca_row2_col1" class="data row2 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_951ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_951ca_row3_col0" class="data row3 col0" >Sawai Mansingh Stadium</td>
#       <td id="T_951ca_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_951ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_951ca_row4_col0" class="data row4 col0" >Sharjah Cricket Stadium</td>
#       <td id="T_951ca_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *HIS FAVOURITE VENUE IS  M Chinnaswamy Stadium WHERE HE TOOK 52 WICKET ,FOLLOWED BY Wankhede Stadium	20 WICKET*

# %% [markdown]
# ### **WHEN HE IS EFFECTIVE**

# %%
c=chahal.groupby('over',as_index=False)['is_wicket'].sum().sort_values(by=['over','is_wicket'],ascending=[True,False])

# %%
c.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_20962_row0_col0, #T_20962_row0_col1, #T_20962_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_20962_row1_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_20962_row1_col1, #T_20962_row2_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_20962_row2_col0 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_20962_row3_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_20962_row3_col1, #T_20962_row4_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_20962_row4_col0 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_20962_row5_col0 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_20962_row5_col1, #T_20962_row18_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_20962_row6_col0 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_20962_row6_col1, #T_20962_row13_col1 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_20962_row7_col0, #T_20962_row17_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_20962_row7_col1 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_20962_row8_col0 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_20962_row8_col1, #T_20962_row10_col1, #T_20962_row16_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_20962_row9_col0 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_20962_row9_col1, #T_20962_row11_col1 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_20962_row10_col0 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_20962_row11_col0 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_20962_row12_col0 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_20962_row12_col1 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_20962_row13_col0 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_20962_row14_col0 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_20962_row14_col1 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_20962_row15_col0 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_20962_row15_col1, #T_20962_row19_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_20962_row16_col0 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_20962_row17_col0 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_20962_row18_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_20962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20962_level0_col0" class="col_heading level0 col0" >over</th>
#       <th id="T_20962_level0_col1" class="col_heading level0 col1" >is_wicket</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20962_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_20962_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20962_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_20962_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20962_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_20962_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20962_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_20962_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20962_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_20962_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20962_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_20962_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20962_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_20962_row6_col1" class="data row6 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20962_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_20962_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20962_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_20962_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20962_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_20962_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20962_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_20962_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20962_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_20962_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20962_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_20962_row12_col1" class="data row12 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20962_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_20962_row13_col1" class="data row13 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_20962_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_20962_row14_col1" class="data row14 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_20962_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_20962_row15_col1" class="data row15 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_20962_row16_col0" class="data row16 col0" >16</td>
#       <td id="T_20962_row16_col1" class="data row16 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_20962_row17_col0" class="data row17 col0" >17</td>
#       <td id="T_20962_row17_col1" class="data row17 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_20962_row18_col0" class="data row18 col0" >18</td>
#       <td id="T_20962_row18_col1" class="data row18 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_20962_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_20962_row19_col0" class="data row19 col0" >19</td>
#       <td id="T_20962_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *CONCLUSION --- HE TOOK 28 WICKETS AT 15'TH OVER ,BETWEEN 6 TO 17 OVERS HE TOOKES MOST OF HIS WICKETS SO HE IS  EFFECTIVE IN MIDDLE OVERS*

# %% [markdown]
# ### **chahal  WICKET PER SEASON**

# %%
c_trend=data_chahal.groupby('season',as_index=False)['is_wicket'].sum().sort_values(by='is_wicket',ascending=False)

# %%
c_trend['is_wicket'] = c_trend['is_wicket'].astype(int)

# %%
fig=go.Figure()
fig.add_trace(
    go.Scatter(
        x=c_trend['season'],
        y=c_trend['is_wicket'],
        mode='lines+markers'
    )

)

fig.update_layout(
    xaxis_title='season',
    yaxis_title='total_wicket',
    title='total wicket in each ipl season',
    template='simple_white'
)

fig.show()
# Out:
# <div>                            <div id="52a0927e-0462-4ec8-8b4f-3b072d9a068e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52a0927e-0462-4ec8-8b4f-3b072d9a068e")) {                    Plotly.newPlot(                        "52a0927e-0462-4ec8-8b4f-3b072d9a068e",                        [{"mode":"lines+markers","x":["2022","2015","2016","2023","2020\u002f21","2021","2019","2024","2017","2018","2014","2009","2013","2012","2011","2009\u002f10","2007\u002f08"],"y":[27,23,21,21,21,18,18,18,14,12,12,0,0,0,0,0,0],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36 ...

# %% [markdown]
# ### *HE TOOK 27 WICKET IN 2022*

# %% [markdown]
# ### **TOTAL RUNS VS TOTAL WICKET PER SEASON**

# %%
c_trend_run=df1[df1['bowler']=='YS Chahal']
data_chahal_run=df2[['id','season','venue']].merge(c_trend_run,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
c_trend_run_season=data_chahal_run.groupby('season',as_index=False)['total_runs'].sum().sort_values(by='total_runs',ascending=False)

# %%
c_trend_run_season['total_runs']=c_trend_run_season['total_runs'].astype(int)

# %%
c_trend_run_season['total_wicket']=c_trend['is_wicket']
c_trend_run_season['total_wicket'] = c_trend_run_season['total_wicket'].fillna(0).astype(int)

# %%
c_run_vs_wicket=c_trend_run_season.reset_index()

# %%
c_run_vs_wicket.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_0371a_row0_col0, #T_0371a_row0_col2, #T_0371a_row1_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0371a_row0_col3, #T_0371a_row6_col3, #T_0371a_row8_col3 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_0371a_row1_col0 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_0371a_row1_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_0371a_row2_col0 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_0371a_row2_col2 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_0371a_row2_col3, #T_0371a_row4_col3, #T_0371a_row5_col3 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_0371a_row3_col0 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_0371a_row3_col2 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_0371a_row3_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_0371a_row4_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_0371a_row4_col2 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_0371a_row5_col0 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_0371a_row5_col2 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_0371a_row6_col0 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_0371a_row6_col2 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_0371a_row7_col0 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_0371a_row7_col2 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_0371a_row7_col3, #T_0371a_row9_col3 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_0371a_row8_col0 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_0371a_row8_col2 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_0371a_row9_col0 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_0371a_row9_col2 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_0371a_row10_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_0371a_row10_col2 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_0371a_row10_col3 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_0371a_row11_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_0371a_row11_col2, #T_0371a_row12_col0 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_0371a_row11_col3, #T_0371a_row12_col2, #T_0371a_row12_col3, #T_0371a_row13_col2, #T_0371a_row13_col3, #T_0371a_row14_col2, #T_0371a_row14_col3, #T_0371a_row15_col2, #T_0371a_row15_col3, #T_0371a_row16_col0, #T_0371a_row16_col2, #T_0371a_row16_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_0371a_row13_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_0371a_row14_col0 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_0371a_row15_col0 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# </style>
# <table id="T_0371a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0371a_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_0371a_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_0371a_level0_col2" class="col_heading level0 col2" >total_runs</th>
#       <th id="T_0371a_level0_col3" class="col_heading level0 col3" >total_wicket</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0371a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0371a_row0_col0" class="data row0 col0" >16</td>
#       <td id="T_0371a_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_0371a_row0_col2" class="data row0 col2" >548</td>
#       <td id="T_0371a_row0_col3" class="data row0 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0371a_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_0371a_row1_col1" class="data row1 col1" >2022</td>
#       <td id="T_0371a_row1_col2" class="data row1 col2" >536</td>
#       <td id="T_0371a_row1_col3" class="data row1 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0371a_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_0371a_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_0371a_row2_col2" class="data row2 col2" >434</td>
#       <td id="T_0371a_row2_col3" class="data row2 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0371a_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_0371a_row3_col1" class="data row3 col1" >2015</td>
#       <td id="T_0371a_row3_col2" class="data row3 col2" >416</td>
#       <td id="T_0371a_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0371a_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_0371a_row4_col1" class="data row4 col1" >2020/21</td>
#       <td id="T_0371a_row4_col2" class="data row4 col2" >414</td>
#       <td id="T_0371a_row4_col3" class="data row4 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0371a_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_0371a_row5_col1" class="data row5 col1" >2016</td>
#       <td id="T_0371a_row5_col2" class="data row5 col2" >409</td>
#       <td id="T_0371a_row5_col3" class="data row5 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0371a_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_0371a_row6_col1" class="data row6 col1" >2019</td>
#       <td id="T_0371a_row6_col2" class="data row6 col2" >394</td>
#       <td id="T_0371a_row6_col3" class="data row6 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0371a_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_0371a_row7_col1" class="data row7 col1" >2014</td>
#       <td id="T_0371a_row7_col2" class="data row7 col2" >389</td>
#       <td id="T_0371a_row7_col3" class="data row7 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0371a_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_0371a_row8_col1" class="data row8 col1" >2021</td>
#       <td id="T_0371a_row8_col2" class="data row8 col2" >381</td>
#       <td id="T_0371a_row8_col3" class="data row8 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0371a_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_0371a_row9_col1" class="data row9 col1" >2018</td>
#       <td id="T_0371a_row9_col2" class="data row9 col2" >374</td>
#       <td id="T_0371a_row9_col3" class="data row9 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0371a_row10_col0" class="data row10 col0" >9</td>
#       <td id="T_0371a_row10_col1" class="data row10 col1" >2017</td>
#       <td id="T_0371a_row10_col2" class="data row10 col2" >351</td>
#       <td id="T_0371a_row10_col3" class="data row10 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0371a_row11_col0" class="data row11 col0" >5</td>
#       <td id="T_0371a_row11_col1" class="data row11 col1" >2013</td>
#       <td id="T_0371a_row11_col2" class="data row11 col2" >35</td>
#       <td id="T_0371a_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0371a_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_0371a_row12_col1" class="data row12 col1" >2009</td>
#       <td id="T_0371a_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_0371a_row12_col3" class="data row12 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0371a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0371a_row13_col0" class="data row13 col0" >4</td>
#       <td id="T_0371a_row13_col1" class="data row13 col1" >2012

# %% [markdown]
# ### *THIS TABLE SHOWS TOTAL RUNS AND TOTAL WICKET PER SEASON*

# %% [markdown]
# ### **HIS FAVOURITE BATSMAN**

# %%
cb=chahal.groupby('batter')['is_wicket'].sum().sort_values(ascending=False).reset_index(name='wicket')

# %%
cb=cb.head(5)
cb
# Out:
#        batter  wicket
# 0  MA Agarwal       6
# 1      N Rana       6
# 2   Q de Kock       6
# 3   SV Samson       5
# 4   AT Rayudu       4

# %%
fig=px.bar(
    cb,
    x="batter",
    y="wicket",
    
     title="Chahal favourite batsman",
     width=600, 
    height=400,
    color="batter",
   
    labels={"wicket": "Total out", "batter": "Batsman"}
    
)
fig.update_layout(bargap=.7,
                 showlegend=False)
fig.show()
# Out:
# <div>                            <div id="e0819622-a590-406a-8ee2-c71cd69d694b" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0819622-a590-406a-8ee2-c71cd69d694b")) {                    Plotly.newPlot(                        "e0819622-a590-406a-8ee2-c71cd69d694b",                        [{"alignmentgroup":"True","hovertemplate":"Batsman=%{x}\u003cbr\u003eTotal out=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MA Agarwal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MA Agarwal","offsetgroup":"MA Agarwal","orientation":"v","showlegend":true,"textposition":"auto","x":["MA Agarwal"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Batsman=%{x}\u003cbr\u003eTotal out=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N Rana","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"N Rana","offsetgroup":"N Rana","orientation":"v","showlegend":true,"textposition":"auto","x":["N Rana"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Batsman=%{x}\u003cbr\u003eTotal out=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Q de Kock","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Q de Kock","offsetgroup":"Q de Kock","orientation":"v","showlegend":true,"textposition":"auto","x":["Q de Kock"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Batsman=%{x}\u003cbr\u003eTotal out=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SV Samson","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"SV Samson","offsetgroup":"SV Samson","orientation":"v","showlegend":true,"textposition":"auto","x":["SV Samson"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Batsman=%{x}\u003cbr\u003eTotal out=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AT Rayudu","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AT Rayudu","offsetgroup":"AT Rayudu","orientation":"v","showlegend":true,"textposition":"auto","x":["AT Rayudu"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"cont ...

# %% [markdown]
# ###  *MA Agarwal GOT OUT 6 TIMES ,FOLLOWED BY N Rana	6 TIMES BY CHAHAL*

# %% [markdown]
# # **Q.14 INNINGS WISE RUN ANALYSIS BY TEAM**

# %% [markdown]
# # FIRST INNINGS

# %%
run=df1.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()

# %%
inning1=run[run['inning']==1]
inning2=run[run['inning']==2]

# %%
fig=px.box(data_frame=inning1,x='batting_team',y='total_runs',color='batting_team',
          width=800,
          height=500)
fig.update_layout(title='Batting first',showlegend=False)
fig.show()
# Out:
# <div>                            <div id="8a101383-9160-4788-8b00-9f66c3bfdddd" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a101383-9160-4788-8b00-9f66c3bfdddd")) {                    Plotly.newPlot(                        "8a101383-9160-4788-8b00-9f66c3bfdddd",                        [{"alignmentgroup":"True","hovertemplate":"batting_team=%{x}\u003cbr\u003etotal_runs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata Knight Riders","marker":{"color":"#636efa"},"name":"Kolkata Knight Riders","notched":false,"offsetgroup":"Kolkata Knight Riders","orientation":"v","showlegend":true,"x":["Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders","Kolkata Knight Riders"],"x0":" ","xaxis":"x","y":[222,147,137,129,204,133,67,149,147,101,139,153,154,123,173,160,161,155,183,181,200,181,160,139,163,171,148,169,89,175,147,97,165,190,150,158,140,136,162,154,180,119,159,136,152,130,163,166,150,195,163,177,171,111,167,187,174,164,158,183,1 ...

# %% [markdown]
# ## *CONCLUSION --- WHILE BATTING FIRST RCB , KKR , DC , SRH , LSG HAD 250+ SCORED ALSO WHILE BATTING FIRST KKR , RCB , DC HAD SCORED LESS THAN 70 RUNS*

# %% [markdown]
# # SECOND INNINGS

# %%
fig=px.box(data_frame=inning2,x='batting_team',y='total_runs',color='batting_team',
          width=800,
          height=500)
fig.update_layout(title='Batting Second',showlegend=False)
fig.show()

# %% [markdown]
# ## **CONCLUSION --- WHILE BOWLING RCB , PBKS THEY BOTH GOT 250 + RUNS**

# %% [markdown]
# # **Q.16 MOST 200+ RUNS BY A BATTNG TEAM AND BOWLING TEAM**

# %% [markdown]
# ## BATTING TEAM

# %%
score=df1.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()

# %%
score_200=score[score['total_runs']>=200]

# %%
score_200
# Out:
#       match_id  inning                 batting_team  \
# 0       335982       1        Kolkata Knight Riders
# 2       335983       1          Chennai Super Kings
# 3       335983       2                 Punjab Kings
# 14      335989       1          Chennai Super Kings
# 15      335989       2               Mumbai Indians
# ...        ...     ...                          ...
# 2199   1426302       1               Delhi Capitals
# 2203   1426305       1         Lucknow Super Giants
# 2205   1426306       1  Royal Challengers Bangalore
# 2207   1426307       1                 Punjab Kings
# 2208   1426307       2          Sunrisers Hyderabad
#
#                      bowling_team  total_runs
# 0     Royal Challengers Bangalore         222
# 2                    Punjab Kings         240
# 3             Chennai Super Kings         207
# 14                 Mumbai Indians         208
# 15            Chennai Super Kings         202
# ...                           ...         ...
# 2199         Lucknow Super Giants         208
# 2203               Mumbai Indians         214
# 2205          Chennai Super Kings         218
# 2207          Sunrisers Hyderabad         214
# 2208                 Punjab Kings         215
#
# [211 rows x 5 columns]

# %%
bat=score_200['batting_team'].value_counts().reset_index().head(5)

# %%
bat.columns=['Team','Total']
bat
# Out:
#                           Team  Total
# 0          Chennai Super Kings     32
# 1  Royal Challengers Bangalore     30
# 2        Kolkata Knight Riders     25
# 3               Mumbai Indians     25
# 4                 Punjab Kings     24

# %%
colors=['crimson']+['turquoise']*(len(bat)-1)
fig=go.Figure(
data=[
  go.Bar( x=bat['Team'],y=bat['Total'],marker_color=colors,width=0.2)
])

fig.update_layout(

    title='Most 200+ scores by a batting team',
    xaxis_title='Team',
    yaxis_title='Total',
    bargap=.5,
    width=600,
    height=400
    
)
fig.show()
# Out:
# <div>                            <div id="869ec5a3-95c5-4e5b-8068-d03ab434d21d" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("869ec5a3-95c5-4e5b-8068-d03ab434d21d")) {                    Plotly.newPlot(                        "869ec5a3-95c5-4e5b-8068-d03ab434d21d",                        [{"marker":{"color":["crimson","turquoise","turquoise","turquoise","turquoise"]},"width":0.2,"x":["Chennai Super Kings","Royal Challengers Bangalore","Kolkata Knight Riders","Mumbai Indians","Punjab Kings"],"y":[32,30,25,25,24],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10 ...
#
# var gd = doc

# %% [markdown]
# ## *CONCLUSION -- CSK ACHIEVED MOST 200+ RUNS WHILE BATTING 32 TIMES FOLLOWED BY RCB 30 TIMS*

# %% [markdown]
# ## BOWLING TEAM

# %%
bowl=score_200['bowling_team'].value_counts().reset_index().head(5)

# %%
bowl.columns=['Team','Total']
bowl
# Out:
#                           Team  Total
# 0                 Punjab Kings     30
# 1  Royal Challengers Bangalore     28
# 2          Chennai Super Kings     23
# 3               Delhi Capitals     23
# 4          Sunrisers Hyderabad     23

# %%
colors=['crimson']+['turquoise']*(len(bat)-1)
fig=go.Figure(
data=[
  go.Bar( x=bowl['Team'],y=bowl['Total'],marker_color=colors,width=0.2)
])

fig.update_layout(

    title='Most 200+ scores by a bowling team',
    xaxis_title='Team',
    yaxis_title='Total',
    bargap=.5,
    width=600,
    height=400
    
)
fig.show()
# Out:
# <div>                            <div id="47e37f5b-b8b3-4d97-9f57-b1e82498dc96" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e37f5b-b8b3-4d97-9f57-b1e82498dc96")) {                    Plotly.newPlot(                        "47e37f5b-b8b3-4d97-9f57-b1e82498dc96",                        [{"marker":{"color":["crimson","turquoise","turquoise","turquoise","turquoise"]},"width":0.2,"x":["Punjab Kings","Royal Challengers Bangalore","Chennai Super Kings","Delhi Capitals","Sunrisers Hyderabad"],"y":[30,28,23,23,23],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10," ...
#
# var gd = docum

# %% [markdown]
# ##  *CONCLUSION --- WHILE BOWLING PBKS HAD ACHIEVED 30 TIMES 200 + RUNS FOLLOWED BY RCB 28 TIMES*

# %% [markdown]
# ## **Q.17 WIN A MATCH WITH MAXIMUN RESULT MARGIN**

# %%
df2[df2['result_margin']==df2['result_margin'].max()]
# Out:
#           id season   city        date match_type player_of_match  \
# 620  1082635   2017  Delhi  2017-05-06     League     LMP Simmons
#
#                     venue           team1           team2     toss_winner  \
# 620  Arun Jaitley Stadium  Delhi Capitals  Mumbai Indians  Delhi Capitals
#
#      ...          winner result result_margin  target_runs  target_overs  \
# 620  ...  Mumbai Indians   runs         146.0        213.0          20.0
#
#      super_over             method      umpire1    umpire2 toss_winner_won
# 620           N  No method applied  Nitin Menon  CK Nandan           False
#
# [1 rows x 21 columns]

# %% [markdown]
# ### *CONCLUSION ---IN 2017 MI VS DC ,MI WON BY A HUGE MARGIN BY 146 RUNS*

# %% [markdown]
# # *Q.18  TEAMS WITH MORE THAN 100+ RESULT MARGIN*

# %%
matches_with_large_margin = df2[df2['result_margin'] > 100]
head_10_large_margin = matches_with_large_margin[['winner', 'team1','team2','result_margin']].head(12)
head_10_large_margin['loss_side'] = head_10_large_margin.apply(
    lambda row: row['team2'] if row['winner'] == row['team1'] else row['team1'], axis=1
)

# Display 'loss_side' and 'result_margin'
result = head_10_large_margin[['winner','loss_side', 'result_margin']].reset_index()

# %%
result
# Out:
#     index                       winner                    loss_side  \
# 0       0        Kolkata Knight Riders  Royal Challengers Bangalore
# 1      55             Rajasthan Royals               Delhi Capitals
# 2     236                 Punjab Kings  Royal Challengers Bangalore
# 3     352  Royal Challengers Bangalore                Pune Warriors
# 4     496  Royal Challengers Bangalore                 Punjab Kings
# 5     560  Royal Challengers Bangalore                Gujarat Lions
# 6     620               Mumbai Indians               Delhi Capitals
# 7     676               Mumbai Indians        Kolkata Knight Riders
# 8     706          Sunrisers Hyderabad  Royal Challengers Bangalore
# 9    1009  Royal Challengers Bangalore             Rajasthan Royals
# 10   1039        Kolkata Knight Riders               Delhi Capitals
#
#     result_margin
# 0           140.0
# 1           105.0
# 2           111.0
# 3           130.0
# 4           138.0
# 5           144.0
# 6           146.0
# 7           102.0
# 8           118.0
# 9           112.0
# 10          106.0

# %% [markdown]
# ### CONCLUSION -- RCB WIN 4 TIMES WITH 100+ RUNS ALSO LOSS 3 TIME WITH 100+

# %% [markdown]
# # **Q.19 BATSMAN WITH MOST NUMBER OF BALL PLAYED**

# %%
highest_ball_played=df1.groupby('batter',as_index=False)['ball'].count().sort_values(by='ball',ascending=False).reset_index(drop='index').head(10)

# %%
highest_ball_played.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_6b46e_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6b46e_row1_col1 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_6b46e_row2_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_6b46e_row3_col1 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_6b46e_row4_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_6b46e_row5_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_6b46e_row6_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_6b46e_row7_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6b46e_row8_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_6b46e_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_6b46e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b46e_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_6b46e_level0_col1" class="col_heading level0 col1" >ball</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b46e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b46e_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_6b46e_row0_col1" class="data row0 col1" >6236</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b46e_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_6b46e_row1_col1" class="data row1 col1" >5483</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b46e_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_6b46e_row2_col1" class="data row2 col1" >5183</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b46e_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_6b46e_row3_col1" class="data row3 col1" >4849</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b46e_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_6b46e_row4_col1" class="data row4 col1" >4177</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b46e_row5_col0" class="data row5 col0" >MS Dhoni</td>
#       <td id="T_6b46e_row5_col1" class="data row5 col1" >3947</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b46e_row6_col0" class="data row6 col0" >RV Uthappa</td>
#       <td id="T_6b46e_row6_col1" class="data row6 col1" >3927</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b46e_row7_col0" class="data row7 col0" >AM Rahane</td>
#       <td id="T_6b46e_row7_col1" class="data row7 col1" >3858</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b46e_row8_col0" class="data row8 col0" >KD Karthik</td>
#       <td id="T_6b46e_row8_col1" class="data row8 col1" >3687</td>
#     </tr>
#     <tr>
#       <th id="T_6b46e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b46e_row9_col0" class="data row9 col0" >KL Rahul</td>
#       <td id="T_6b46e_row9_col1" class="data row9 col1" >3578</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### CONCLUSION --- CLEARLY KING KOHLI PLAYED MOST BALLS 6326 BALLS, FOLLOWED BY S Dhawan 5483 BALLS,RG Sharma 5183 BALLS

# %% [markdown]
# # **Q.20 MOST NUMBER OF 6'S**

# %%
six=df1.groupby('batter')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()
six.columns=['batter','6s']
six=six.sort_values(by='6s',ascending=False).head(10).reset_index(drop='index')
six.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_14aad_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_14aad_row1_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_14aad_row2_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_14aad_row3_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_14aad_row4_col1 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_14aad_row5_col1 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_14aad_row6_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_14aad_row7_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_14aad_row8_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_14aad_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_14aad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14aad_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_14aad_level0_col1" class="col_heading level0 col1" >6s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14aad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14aad_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_14aad_row0_col1" class="data row0 col1" >359</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14aad_row1_col0" class="data row1 col0" >RG Sharma</td>
#       <td id="T_14aad_row1_col1" class="data row1 col1" >281</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14aad_row2_col0" class="data row2 col0" >V Kohli</td>
#       <td id="T_14aad_row2_col1" class="data row2 col1" >273</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14aad_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_14aad_row3_col1" class="data row3 col1" >253</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14aad_row4_col0" class="data row4 col0" >MS Dhoni</td>
#       <td id="T_14aad_row4_col1" class="data row4 col1" >252</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14aad_row5_col0" class="data row5 col0" >DA Warner</td>
#       <td id="T_14aad_row5_col1" class="data row5 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14aad_row6_col0" class="data row6 col0" >KA Pollard</td>
#       <td id="T_14aad_row6_col1" class="data row6 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14aad_row7_col0" class="data row7 col0" >AD Russell</td>
#       <td id="T_14aad_row7_col1" class="data row7 col1" >209</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14aad_row8_col0" class="data row8 col0" >SV Samson</td>
#       <td id="T_14aad_row8_col1" class="data row8 col1" >206</td>
#     </tr>
#     <tr>
#       <th id="T_14aad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14aad_row9_col0" class="data row9 col0" >SK Raina</td>
#       <td id="T_14aad_row9_col1" class="data row9 col1" >204</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###  CONCLUSION -- UNIVERSE BOSS CONQUER WITH 359 SIXS, RG Sharma	281 SIXS, FOLLOWED BY KOHLI 273 SIXS

# %% [markdown]
# # **Q.21 MOST NUMBER OF 4'S**

# %%
six=df1.groupby('batter')['batsman_runs'].agg(lambda x: (x==4).sum()).reset_index()
six.columns=['batter','4s']
six=six.sort_values(by='4s',ascending=False).head(10).reset_index(drop='index')
six.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_25e77_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_25e77_row1_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_25e77_row2_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_25e77_row3_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_25e77_row4_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_25e77_row5_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_25e77_row6_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_25e77_row7_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_25e77_row8_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_25e77_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_25e77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25e77_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_25e77_level0_col1" class="col_heading level0 col1" >4s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25e77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25e77_row0_col0" class="data row0 col0" >S Dhawan</td>
#       <td id="T_25e77_row0_col1" class="data row0 col1" >768</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25e77_row1_col0" class="data row1 col0" >V Kohli</td>
#       <td id="T_25e77_row1_col1" class="data row1 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25e77_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_25e77_row2_col1" class="data row2 col1" >663</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25e77_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_25e77_row3_col1" class="data row3 col1" >599</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25e77_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_25e77_row4_col1" class="data row4 col1" >506</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25e77_row5_col0" class="data row5 col0" >G Gambhir</td>
#       <td id="T_25e77_row5_col1" class="data row5 col1" >492</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_25e77_row6_col0" class="data row6 col0" >RV Uthappa</td>
#       <td id="T_25e77_row6_col1" class="data row6 col1" >481</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_25e77_row7_col0" class="data row7 col0" >AM Rahane</td>
#       <td id="T_25e77_row7_col1" class="data row7 col1" >479</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_25e77_row8_col0" class="data row8 col0" >KD Karthik</td>
#       <td id="T_25e77_row8_col1" class="data row8 col1" >466</td>
#     </tr>
#     <tr>
#       <th id="T_25e77_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_25e77_row9_col0" class="data row9 col0" >F du Plessis</td>
#       <td id="T_25e77_row9_col1" class="data row9 col1" >422</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### CONCLUSION  S Dhawan HITS  768,V Kohli	708 AND FOLLOWED BY DA Warner	663 FOURS

# %% [markdown]
# # **Q.22 WICKET KEEPER WITH MOST NUMBER OF STUMPED**

# %%
dismissal_kindss=['stumped']

# %%
keeper=df1[df1['dismissal_kind'] .isin (dismissal_kindss)]

# %%
keeper['dismissal_kind'].value_counts()
# Out:
# stumped    358
# Name: dismissal_kind, dtype: int64

# %%
wicket_keeper=keeper.groupby(['fielder', 'dismissal_kind']).size().reset_index(name='count')

# %%
wicket_keeper=wicket_keeper.sort_values(by='count',ascending=False).head(10).reset_index(drop='index')

# %%
wicket_keeper.style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_9c94d_row0_col2 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_9c94d_row1_col2 {
#   background-color: #00d893;
#   color: #000000;
# }
# #T_9c94d_row2_col2 {
#   background-color: #00b0a7;
#   color: #f1f1f1;
# }
# #T_9c94d_row3_col2 {
#   background-color: #0080bf;
#   color: #f1f1f1;
# }
# #T_9c94d_row4_col2 {
#   background-color: #0068cb;
#   color: #f1f1f1;
# }
# #T_9c94d_row5_col2, #T_9c94d_row6_col2, #T_9c94d_row7_col2, #T_9c94d_row8_col2 {
#   background-color: #0030e7;
#   color: #f1f1f1;
# }
# #T_9c94d_row9_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c94d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c94d_level0_col0" class="col_heading level0 col0" >fielder</th>
#       <th id="T_9c94d_level0_col1" class="col_heading level0 col1" >dismissal_kind</th>
#       <th id="T_9c94d_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c94d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c94d_row0_col0" class="data row0 col0" >MS Dhoni</td>
#       <td id="T_9c94d_row0_col1" class="data row0 col1" >stumped</td>
#       <td id="T_9c94d_row0_col2" class="data row0 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c94d_row1_col0" class="data row1 col0" >KD Karthik</td>
#       <td id="T_9c94d_row1_col1" class="data row1 col1" >stumped</td>
#       <td id="T_9c94d_row1_col2" class="data row1 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c94d_row2_col0" class="data row2 col0" >RV Uthappa</td>
#       <td id="T_9c94d_row2_col1" class="data row2 col1" >stumped</td>
#       <td id="T_9c94d_row2_col2" class="data row2 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c94d_row3_col0" class="data row3 col0" >WP Saha</td>
#       <td id="T_9c94d_row3_col1" class="data row3 col1" >stumped</td>
#       <td id="T_9c94d_row3_col2" class="data row3 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c94d_row4_col0" class="data row4 col0" >RR Pant</td>
#       <td id="T_9c94d_row4_col1" class="data row4 col1" >stumped</td>
#       <td id="T_9c94d_row4_col2" class="data row4 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c94d_row5_col0" class="data row5 col0" >PA Patel</td>
#       <td id="T_9c94d_row5_col1" class="data row5 col1" >stumped</td>
#       <td id="T_9c94d_row5_col2" class="data row5 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c94d_row6_col0" class="data row6 col0" >Q de Kock</td>
#       <td id="T_9c94d_row6_col1" class="data row6 col1" >stumped</td>
#       <td id="T_9c94d_row6_col2" class="data row6 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c94d_row7_col0" class="data row7 col0" >AC Gilchrist</td>
#       <td id="T_9c94d_row7_col1" class="data row7 col1" >stumped</td>
#       <td id="T_9c94d_row7_col2" class="data row7 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c94d_row8_col0" class="data row8 col0" >SV Samson</td>
#       <td id="T_9c94d_row8_col1" class="data row8 col1" >stumped</td>
#       <td id="T_9c94d_row8_col2" class="data row8 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9c94d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c94d_row9_col0" class="data row9 col0" >NV Ojha</td>
#       <td id="T_9c94d_row9_col1" class="data row9 col1" >stumped</td>
#       <td id="T_9c94d_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  ### CONCLUSION -- MS Dhoni	stumped	42 ,FOLLOWED BY KD Karthik	stumped	37,AND RV Uthappa	stumped	32 ALL THREE INDIAN

# %% [markdown]
# # **Q.23 HIGHEST STRIKE RATE DURING DEATH OVER**

# %%
valid_deliveries = df1[~df1['extras_type'].isin(['wides','byes','penalty'])]

# %%
df_filtered = valid_deliveries[(valid_deliveries['over'] >= 16) & (valid_deliveries['over'] <= 20)]

# %%
# Recalculate ball count faced by each batter
ball_face_count = df_filtered.groupby('batter').size().reset_index(name='ball_face')

# Recalculate total runs scored by each batter
total_runs_count = df_filtered.groupby('batter')['batsman_runs'].sum().reset_index(name='total_runs')
batter_stats = pd.merge(total_runs_count, ball_face_count, on='batter', how='inner')

# %%
filtered_batters=batter_stats[batter_stats['ball_face'] > 250]
filtered_batters = filtered_batters.copy()

filtered_batters['strike_rate'] = (filtered_batters['total_runs'] / filtered_batters['ball_face']) * 100
batter_stats_over_100 = filtered_batters.sort_values(by='strike_rate',ascending=False).head(10)

# %%
batter_death_over = batter_stats_over_100.reset_index(drop='index')

# %%
batter_death_over.style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_38bf2_row0_col1 {
#   background-color: #0066cc;
#   color: #f1f1f1;
# }
# #T_38bf2_row0_col2 {
#   background-color: #0048db;
#   color: #f1f1f1;
# }
# #T_38bf2_row0_col3, #T_38bf2_row8_col1, #T_38bf2_row8_col2 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_38bf2_row1_col1, #T_38bf2_row8_col3 {
#   background-color: #000cf9;
#   color: #f1f1f1;
# }
# #T_38bf2_row1_col2 {
#   background-color: #0007fc;
#   color: #f1f1f1;
# }
# #T_38bf2_row1_col3 {
#   background-color: #006cc9;
#   color: #f1f1f1;
# }
# #T_38bf2_row2_col1, #T_38bf2_row4_col3 {
#   background-color: #003de0;
#   color: #f1f1f1;
# }
# #T_38bf2_row2_col2 {
#   background-color: #0035e4;
#   color: #f1f1f1;
# }
# #T_38bf2_row2_col3 {
#   background-color: #005cd1;
#   color: #f1f1f1;
# }
# #T_38bf2_row3_col1 {
#   background-color: #0041de;
#   color: #f1f1f1;
# }
# #T_38bf2_row3_col2 {
#   background-color: #003ae2;
#   color: #f1f1f1;
# }
# #T_38bf2_row3_col3 {
#   background-color: #004dd8;
#   color: #f1f1f1;
# }
# #T_38bf2_row4_col1 {
#   background-color: #0012f6;
#   color: #f1f1f1;
# }
# #T_38bf2_row4_col2 {
#   background-color: #000ff8;
#   color: #f1f1f1;
# }
# #T_38bf2_row5_col1 {
#   background-color: #004ada;
#   color: #f1f1f1;
# }
# #T_38bf2_row5_col2 {
#   background-color: #0046dc;
#   color: #f1f1f1;
# }
# #T_38bf2_row5_col3 {
#   background-color: #0031e6;
#   color: #f1f1f1;
# }
# #T_38bf2_row6_col1 {
#   background-color: #0003fe;
#   color: #f1f1f1;
# }
# #T_38bf2_row6_col2 {
#   background-color: #0002fe;
#   color: #f1f1f1;
# }
# #T_38bf2_row6_col3 {
#   background-color: #002aea;
#   color: #f1f1f1;
# }
# #T_38bf2_row7_col1, #T_38bf2_row7_col2, #T_38bf2_row9_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_38bf2_row7_col3 {
#   background-color: #0016f4;
#   color: #f1f1f1;
# }
# #T_38bf2_row9_col1 {
#   background-color: #0076c4;
#   color: #f1f1f1;
# }
# #T_38bf2_row9_col2 {
#   background-color: #0078c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38bf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38bf2_level0_col0" class="col_heading level0 col0" >batter</th>
#       <th id="T_38bf2_level0_col1" class="col_heading level0 col1" >total_runs</th>
#       <th id="T_38bf2_level0_col2" class="col_heading level0 col2" >ball_face</th>
#       <th id="T_38bf2_level0_col3" class="col_heading level0 col3" >strike_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38bf2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38bf2_row0_col0" class="data row0 col0" >AB de Villiers</td>
#       <td id="T_38bf2_row0_col1" class="data row0 col1" >1421</td>
#       <td id="T_38bf2_row0_col2" class="data row0 col2" >607</td>
#       <td id="T_38bf2_row0_col3" class="data row0 col3" >234.102142</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38bf2_row1_col0" class="data row1 col0" >RR Pant</td>
#       <td id="T_38bf2_row1_col1" class="data row1 col1" >626</td>
#       <td id="T_38bf2_row1_col2" class="data row1 col2" >302</td>
#       <td id="T_38bf2_row1_col3" class="data row1 col3" >207.284768</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38bf2_row2_col0" class="data row2 col0" >AD Russell</td>
#       <td id="T_38bf2_row2_col1" class="data row2 col1" >1065</td>
#       <td id="T_38bf2_row2_col2" class="data row2 col2" >521</td>
#       <td id="T_38bf2_row2_col3" class="data row2 col3" >204.414587</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38bf2_row3_col0" class="data row3 col0" >V Kohli</td>
#       <td id="T_38bf2_row3_col1" class="data row3 col1" >1099</td>
#       <td id="T_38bf2_row3_col2" class="data row3 col2" >545</td>
#       <td id="T_38bf2_row3_col3" class="data row3 col3" >201.651376</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38bf2_row4_col0" class="data row4 col0" >SO Hetmyer</td>
#       <td id="T_38bf2_row4_col1" class="data row4 col1" >680</td>
#       <td id="T_38bf2_row4_col2" class="data row4 col2" >342</td>
#       <td id="T_38bf2_row4_col3" class="data row4 col3" >198.830409</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38bf2_row5_col0" class="data row5 col0" >RG Sharma</td>
#       <td id="T_38bf2_row5_col1" class="data row5 col1" >1176</td>
#       <td id="T_38bf2_row5_col2" class="data row5 col2" >598</td>
#       <td id="T_38bf2_row5_col3" class="data row5 col3" >196.655518</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38bf2_row6_col0" class="data row6 col0" >SV Samson</td>
#       <td id="T_38bf2_row6_col1" class="data row6 col1" >547</td>
#       <td id="T_38bf2_row6_col2" class="data row6 col2" >280</td>
#       <td id="T_38bf2_row6_col3" class="data row6 col3" >195.357143</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38bf2_row7_col0" class="data row7 col0" >SA Yadav</td>
#       <td id="T_38bf2_row7_col1" class="data row7 col1" >516</td>
#       <td id="T_38bf2_row7_col2" class="data row7 col2" >269</td>
#       <td id="T_38bf2_row7_col3" class="data row7 col3" >191.821561</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38bf2_row8_col0" class="data row8 col0" >MS Dhoni</td>
#       <td id="T_38bf2_row8_col1" class="data row8 col1" >2786</td>
#       <td id="T_38bf2_row8_col2" class="data row8 col2" >1467</td>
#       <td id="T_38bf2_row8_col3" class="data row8 col3" >189.911384</td>
#     </tr>
#     <tr>
#       <th id="T_38bf2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38bf2_row9_col0" class="data row9 col0" >KD Karthik</td>
#       <td id="T_38bf2_row9_col1" class="data row9 col1" >1565</td>
#       <td id="T_38bf2_row9_col2" class="data row9 col2" >834</td>
#       <td id="T_38bf2_row9_col3" class="data row9 col3" >187.649880</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### conclusion --- AB de Villiers with 1421 runs 607 ball played and 234.10 STRIKE RATE HOLD THE RECORD ,WHILE DHONI DURING DEATH OVER SCORED 2786 RUNS

# %% [markdown]
# # **Q.24 MOST MOM PLAYER**

# %%
man_of_the_match=df2['player_of_match'].value_counts().head(10).reset_index()

# %%
man_of_the_match.columns=['player','MoM']

# %%
man_of_the_match.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_6ec29_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6ec29_row1_col1 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_6ec29_row2_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_6ec29_row3_col1, #T_6ec29_row4_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_6ec29_row5_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_6ec29_row6_col1, #T_6ec29_row7_col1, #T_6ec29_row8_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6ec29_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_6ec29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ec29_level0_col0" class="col_heading level0 col0" >player</th>
#       <th id="T_6ec29_level0_col1" class="col_heading level0 col1" >MoM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ec29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ec29_row0_col0" class="data row0 col0" >AB de Villiers</td>
#       <td id="T_6ec29_row0_col1" class="data row0 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ec29_row1_col0" class="data row1 col0" >CH Gayle</td>
#       <td id="T_6ec29_row1_col1" class="data row1 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ec29_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_6ec29_row2_col1" class="data row2 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ec29_row3_col0" class="data row3 col0" >DA Warner</td>
#       <td id="T_6ec29_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ec29_row4_col0" class="data row4 col0" >V Kohli</td>
#       <td id="T_6ec29_row4_col1" class="data row4 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ec29_row5_col0" class="data row5 col0" >MS Dhoni</td>
#       <td id="T_6ec29_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ec29_row6_col0" class="data row6 col0" >SR Watson</td>
#       <td id="T_6ec29_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ec29_row7_col0" class="data row7 col0" >YK Pathan</td>
#       <td id="T_6ec29_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ec29_row8_col0" class="data row8 col0" >RA Jadeja</td>
#       <td id="T_6ec29_row8_col1" class="data row8 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6ec29_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ec29_row9_col0" class="data row9 col0" >AD Russell</td>
#       <td id="T_6ec29_row9_col1" class="data row9 col1" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
colors=['crimson']+['turquoise']*(len(man_of_the_match)-1)
fig=go.Figure(
data=[
  go.Bar( x=man_of_the_match['player'],y=man_of_the_match['MoM'],marker_color=colors,width=0.4)
])

fig.update_layout(

    title='Most Man Ot The Match Award',
    xaxis_title='player',
    yaxis_title='Count',
    bargap=.9,
    width=600,
    height=400
    
)
fig.show()
# Out:
# <div>                            <div id="bd165e59-772b-4f9e-98c2-0d265f850ea2" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd165e59-772b-4f9e-98c2-0d265f850ea2")) {                    Plotly.newPlot(                        "bd165e59-772b-4f9e-98c2-0d265f850ea2",                        [{"marker":{"color":["crimson","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise","turquoise"]},"width":0.4,"x":["AB de Villiers","CH Gayle","RG Sharma","DA Warner","V Kohli","MS Dhoni","SR Watson","YK Pathan","RA Jadeja","AD Russell"],"y":[25,22,19,18,18,17,16,16,16,15],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outline ...

# %% [markdown]
# ### CONCLUSION --- AB de Villiers WITH	25,CH Gayle	WITH 22,FOLLOWED BY RG Sharma WITH 	19 MOM AWARD ARE THE TOP THREE

# %% [markdown]
# # **Q.25 BEST RUN RATE DURING POWER PLAY AND DEATH OVER (2024)**

# %% [markdown]
# ## DURING POWER PLAY

# %%
powerplay=df2[['id','season','venue']].merge(df1,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
powerplay_data_2024 = powerplay[(powerplay['season'] == '2024') & (powerplay['over'] >= 0) & (powerplay['over'] <= 5)]

# %%
powerplay_data=powerplay_data_2024.groupby('batting_team').agg(
    total_runs=('total_runs','sum'),
    ball_face=('ball','count')
).sort_values(by='total_runs',ascending=False)
powerplay_data
# Out:
#                              total_runs  ball_face
# batting_team
# Sunrisers Hyderabad                1073        605
# Kolkata Knight Riders               930        531
# Delhi Capitals                      897        531
# Royal Challengers Bangalore         876        552
# Mumbai Indians                      789        526
# Rajasthan Royals                    773        564
# Punjab Kings                        743        519
# Chennai Super Kings                 733        521
# Lucknow Super Giants                695        524
# Gujarat Titans                      556        450

# %%
extra_balls_data1 = powerplay_data_2024[powerplay_data_2024['extras_type'].notnull() & 
    ~powerplay_data_2024['extras_type'].isin(['byes','legbyes'])]

extra_balls_count1 = extra_balls_data1.groupby('batting_team').agg(
    extra_balls=('extras_type','count')
).sort_values(by='extra_balls', ascending=False)

# %%
extra_balls_count1
# Out:
#                              extra_balls
# batting_team
# Sunrisers Hyderabad                   29
# Delhi Capitals                        26
# Kolkata Knight Riders                 26
# Rajasthan Royals                      24
# Mumbai Indians                        21
# Lucknow Super Giants                  20
# Chennai Super Kings                   17
# Gujarat Titans                        17
# Punjab Kings                          15
# Royal Challengers Bangalore           12

# %%
powerplay_data['ActualBall_Face']=powerplay_data['ball_face']-extra_balls_count1['extra_balls']

# %%
powerplay_data=powerplay_data.drop('ball_face',axis=1)

# %%
powerplay_data
# Out:
#                              total_runs  ActualBall_Face
# batting_team
# Sunrisers Hyderabad                1073              576
# Kolkata Knight Riders               930              505
# Delhi Capitals                      897              505
# Royal Challengers Bangalore         876              540
# Mumbai Indians                      789              505
# Rajasthan Royals                    773              540
# Punjab Kings                        743              504
# Chennai Super Kings                 733              504
# Lucknow Super Giants                695              504
# Gujarat Titans                      556              433

# %%
powerplay_data['RR']=round(((powerplay_data['total_runs']/powerplay_data['ActualBall_Face'])*6),2)

# %%
powerplay_data=powerplay_data.sort_values(by='RR',ascending=False)

# %%
powerplay_data.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_392bc_row0_col0, #T_392bc_row0_col1, #T_392bc_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_392bc_row1_col0 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_392bc_row1_col1, #T_392bc_row2_col1, #T_392bc_row4_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_392bc_row1_col2 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_392bc_row2_col0 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_392bc_row2_col2 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_392bc_row3_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_392bc_row3_col1, #T_392bc_row7_col1 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_392bc_row3_col2 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_392bc_row4_col0 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_392bc_row4_col2 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_392bc_row5_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_392bc_row5_col1, #T_392bc_row6_col1, #T_392bc_row8_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_392bc_row5_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_392bc_row6_col0 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_392bc_row6_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_392bc_row7_col0 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_392bc_row7_col2 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_392bc_row8_col0 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_392bc_row8_col2 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_392bc_row9_col0, #T_392bc_row9_col1, #T_392bc_row9_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_392bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_392bc_level0_col0" class="col_heading level0 col0" >total_runs</th>
#       <th id="T_392bc_level0_col1" class="col_heading level0 col1" >ActualBall_Face</th>
#       <th id="T_392bc_level0_col2" class="col_heading level0 col2" >RR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >batting_team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_392bc_level0_row0" class="row_heading level0 row0" >Sunrisers Hyderabad</th>
#       <td id="T_392bc_row0_col0" class="data row0 col0" >1073</td>
#       <td id="T_392bc_row0_col1" class="data row0 col1" >576</td>
#       <td id="T_392bc_row0_col2" class="data row0 col2" >11.180000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row1" class="row_heading level0 row1" >Kolkata Knight Riders</th>
#       <td id="T_392bc_row1_col0" class="data row1 col0" >930</td>
#       <td id="T_392bc_row1_col1" class="data row1 col1" >505</td>
#       <td id="T_392bc_row1_col2" class="data row1 col2" >11.050000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row2" class="row_heading level0 row2" >Delhi Capitals</th>
#       <td id="T_392bc_row2_col0" class="data row2 col0" >897</td>
#       <td id="T_392bc_row2_col1" class="data row2 col1" >505</td>
#       <td id="T_392bc_row2_col2" class="data row2 col2" >10.660000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row3" class="row_heading level0 row3" >Royal Challengers Bangalore</th>
#       <td id="T_392bc_row3_col0" class="data row3 col0" >876</td>
#       <td id="T_392bc_row3_col1" class="data row3 col1" >540</td>
#       <td id="T_392bc_row3_col2" class="data row3 col2" >9.730000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row4" class="row_heading level0 row4" >Mumbai Indians</th>
#       <td id="T_392bc_row4_col0" class="data row4 col0" >789</td>
#       <td id="T_392bc_row4_col1" class="data row4 col1" >505</td>
#       <td id="T_392bc_row4_col2" class="data row4 col2" >9.370000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row5" class="row_heading level0 row5" >Punjab Kings</th>
#       <td id="T_392bc_row5_col0" class="data row5 col0" >743</td>
#       <td id="T_392bc_row5_col1" class="data row5 col1" >504</td>
#       <td id="T_392bc_row5_col2" class="data row5 col2" >8.850000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row6" class="row_heading level0 row6" >Chennai Super Kings</th>
#       <td id="T_392bc_row6_col0" class="data row6 col0" >733</td>
#       <td id="T_392bc_row6_col1" class="data row6 col1" >504</td>
#       <td id="T_392bc_row6_col2" class="data row6 col2" >8.730000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row7" class="row_heading level0 row7" >Rajasthan Royals</th>
#       <td id="T_392bc_row7_col0" class="data row7 col0" >773</td>
#       <td id="T_392bc_row7_col1" class="data row7 col1" >540</td>
#       <td id="T_392bc_row7_col2" class="data row7 col2" >8.590000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row8" class="row_heading level0 row8" >Lucknow Super Giants</th>
#       <td id="T_392bc_row8_col0" class="data row8 col0" >695</td>
#       <td id="T_392bc_row8_col1" class="data row8 col1" >504</td>
#       <td id="T_392bc_row8_col2" class="data row8 col2" >8.270000</td>
#     </tr>
#     <tr>
#       <th id="T_392bc_level0_row9" class="row_heading level0 row9" >Gujarat Titans</th>
#       <td id="T_392bc_row9_col0" class="data row9 col0" >556</td>
#       <td id="T_392bc_row9_col1" class="data row9 col1" >433</td>
#       <td id="T_392bc_row9_col2" class="data row9 col2" >7.700000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## CONCLUSION --- SRH , KKR , DC BOTH THE TEAM HAVE 10+ RUN RATE DURING POWER PLAY

# %% [markdown]
# ## DURING DEATH OVER

# %%
death=df2[['id','season','venue']].merge(df1,left_on='id',right_on='match_id',how='left').drop('match_id',axis=1)

# %%
deathover_data_2024 = death[(death['season'] == '2024') & (death['over'] >= 16) & (death['over'] <= 20)]
# valid_deliveries = powerplay_data_2024[powerplay_data_2024['extras_type'].isin(['wide', 'byes', 'legbyes'])]

# %%
deathover_data=deathover_data_2024.groupby('batting_team').agg(
    total_runs=('total_runs','sum'),
    ball_face=('ball','count')
).sort_values(by='total_runs',ascending=False)
deathover_data
# Out:
#                              total_runs  ball_face
# batting_team
# Sunrisers Hyderabad                 615        348
# Royal Challengers Bangalore         611        338
# Chennai Super Kings                 608        332
# Rajasthan Royals                    560        329
# Lucknow Super Giants                531        320
# Delhi Capitals                      523        289
# Mumbai Indians                      514        291
# Punjab Kings                        514        306
# Gujarat Titans                      465        275
# Kolkata Knight Riders               432        225

# %%
extra_balls_data = deathover_data_2024[deathover_data_2024['extras_type'].notnull() & 
    ~deathover_data_2024['extras_type'].isin(['byes','legbyes'])]
extra_balls_count = extra_balls_data.groupby('batting_team').agg(
    extra_balls=('extras_type', 'count')
).sort_values(by='extra_balls', ascending=False)

# %%
extra_balls_count
# Out:
#                              extra_balls
# batting_team
# Royal Challengers Bangalore           32
# Chennai Super Kings                   28
# Mumbai Indians                        26
# Punjab Kings                          26
# Kolkata Knight Riders                 25
# Sunrisers Hyderabad                   23
# Gujarat Titans                        22
# Lucknow Super Giants                  20
# Rajasthan Royals                      19
# Delhi Capitals                        14

# %%
deathover_data['ActualBall_Face']=deathover_data['ball_face']-extra_balls_count['extra_balls']

# %%
deathover_data=deathover_data.drop('ball_face',axis=1)

# %%
deathover_data
# Out:
#                              total_runs  ActualBall_Face
# batting_team
# Sunrisers Hyderabad                 615              325
# Royal Challengers Bangalore         611              306
# Chennai Super Kings                 608              304
# Rajasthan Royals                    560              310
# Lucknow Super Giants                531              300
# Delhi Capitals                      523              275
# Mumbai Indians                      514              265
# Punjab Kings                        514              280
# Gujarat Titans                      465              253
# Kolkata Knight Riders               432              200

# %%
deathover_data['RR']=round(((deathover_data['total_runs']/deathover_data['ActualBall_Face'])*6),2)

# %%
deathover_data=deathover_data.sort_values(by='RR',ascending=False)

# %%
deathover_data.style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_eb658_row0_col0, #T_eb658_row0_col1, #T_eb658_row9_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_eb658_row0_col2, #T_eb658_row5_col0, #T_eb658_row5_col1 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_eb658_row1_col0 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_eb658_row1_col1 {
#   background-color: #00d495;
#   color: #000000;
# }
# #T_eb658_row1_col2 {
#   background-color: #0096b4;
#   color: #f1f1f1;
# }
# #T_eb658_row2_col0 {
#   background-color: #00fa82;
#   color: #000000;
# }
# #T_eb658_row2_col1 {
#   background-color: #00d992;
#   color: #000000;
# }
# #T_eb658_row2_col2 {
#   background-color: #0094b5;
#   color: #f1f1f1;
# }
# #T_eb658_row3_col0, #T_eb658_row7_col0 {
#   background-color: #0072c6;
#   color: #f1f1f1;
# }
# #T_eb658_row3_col1 {
#   background-color: #0085bc;
#   color: #f1f1f1;
# }
# #T_eb658_row3_col2 {
#   background-color: #006fc8;
#   color: #f1f1f1;
# }
# #T_eb658_row4_col0 {
#   background-color: #007fc0;
#   color: #f1f1f1;
# }
# #T_eb658_row4_col1 {
#   background-color: #0099b2;
#   color: #f1f1f1;
# }
# #T_eb658_row4_col2 {
#   background-color: #0056d4;
#   color: #f1f1f1;
# }
# #T_eb658_row5_col2 {
#   background-color: #004fd8;
#   color: #f1f1f1;
# }
# #T_eb658_row6_col0 {
#   background-color: #002ee8;
#   color: #f1f1f1;
# }
# #T_eb658_row6_col1 {
#   background-color: #006cc9;
#   color: #f1f1f1;
# }
# #T_eb658_row6_col2 {
#   background-color: #002ce9;
#   color: #f1f1f1;
# }
# #T_eb658_row7_col1 {
#   background-color: #00a3ae;
#   color: #f1f1f1;
# }
# #T_eb658_row7_col2 {
#   background-color: #002aea;
#   color: #f1f1f1;
# }
# #T_eb658_row8_col0 {
#   background-color: #00b3a6;
#   color: #f1f1f1;
# }
# #T_eb658_row8_col1 {
#   background-color: #00e18e;
#   color: #000000;
# }
# #T_eb658_row8_col2 {
#   background-color: #0018f3;
#   color: #f1f1f1;
# }
# #T_eb658_row9_col0 {
#   background-color: #008aba;
#   color: #f1f1f1;
# }
# #T_eb658_row9_col1 {
#   background-color: #00cc99;
#   color: #000000;
# }
# </style>
# <table id="T_eb658">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb658_level0_col0" class="col_heading level0 col0" >total_runs</th>
#       <th id="T_eb658_level0_col1" class="col_heading level0 col1" >ActualBall_Face</th>
#       <th id="T_eb658_level0_col2" class="col_heading level0 col2" >RR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >batting_team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb658_level0_row0" class="row_heading level0 row0" >Kolkata Knight Riders</th>
#       <td id="T_eb658_row0_col0" class="data row0 col0" >432</td>
#       <td id="T_eb658_row0_col1" class="data row0 col1" >200</td>
#       <td id="T_eb658_row0_col2" class="data row0 col2" >12.960000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row1" class="row_heading level0 row1" >Chennai Super Kings</th>
#       <td id="T_eb658_row1_col0" class="data row1 col0" >608</td>
#       <td id="T_eb658_row1_col1" class="data row1 col1" >304</td>
#       <td id="T_eb658_row1_col2" class="data row1 col2" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row2" class="row_heading level0 row2" >Royal Challengers Bangalore</th>
#       <td id="T_eb658_row2_col0" class="data row2 col0" >611</td>
#       <td id="T_eb658_row2_col1" class="data row2 col1" >306</td>
#       <td id="T_eb658_row2_col2" class="data row2 col2" >11.980000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row3" class="row_heading level0 row3" >Mumbai Indians</th>
#       <td id="T_eb658_row3_col0" class="data row3 col0" >514</td>
#       <td id="T_eb658_row3_col1" class="data row3 col1" >265</td>
#       <td id="T_eb658_row3_col2" class="data row3 col2" >11.640000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row4" class="row_heading level0 row4" >Delhi Capitals</th>
#       <td id="T_eb658_row4_col0" class="data row4 col0" >523</td>
#       <td id="T_eb658_row4_col1" class="data row4 col1" >275</td>
#       <td id="T_eb658_row4_col2" class="data row4 col2" >11.410000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row5" class="row_heading level0 row5" >Sunrisers Hyderabad</th>
#       <td id="T_eb658_row5_col0" class="data row5 col0" >615</td>
#       <td id="T_eb658_row5_col1" class="data row5 col1" >325</td>
#       <td id="T_eb658_row5_col2" class="data row5 col2" >11.350000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row6" class="row_heading level0 row6" >Gujarat Titans</th>
#       <td id="T_eb658_row6_col0" class="data row6 col0" >465</td>
#       <td id="T_eb658_row6_col1" class="data row6 col1" >253</td>
#       <td id="T_eb658_row6_col2" class="data row6 col2" >11.030000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row7" class="row_heading level0 row7" >Punjab Kings</th>
#       <td id="T_eb658_row7_col0" class="data row7 col0" >514</td>
#       <td id="T_eb658_row7_col1" class="data row7 col1" >280</td>
#       <td id="T_eb658_row7_col2" class="data row7 col2" >11.010000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row8" class="row_heading level0 row8" >Rajasthan Royals</th>
#       <td id="T_eb658_row8_col0" class="data row8 col0" >560</td>
#       <td id="T_eb658_row8_col1" class="data row8 col1" >310</td>
#       <td id="T_eb658_row8_col2" class="data row8 col2" >10.840000</td>
#     </tr>
#     <tr>
#       <th id="T_eb658_level0_row9" class="row_heading level0 row9" >Lucknow Super Giants</th>
#       <td id="T_eb658_row9_col0" class="data row9 col0" >531</td>
#       <td id="T_eb658_row9_col1" class="data row9 col1" >300</td>
#       <td id="T_eb658_row9_col2" class="data row9 col2" >10.620000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # KKR HAVE A RUN RATE ABOUT 13 DURING DEATH OVER WHERE SRH SCORED 615 RUN WITH A 11.13 RUN RATE DURING DEATH OVER
